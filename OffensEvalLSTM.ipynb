# %% [markdown]
# <a href="https://colab.research.google.com/github/binxuankong/basic-tweet-bot/blob/master/OffensEvalLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import copy
import re
import numpy as np
import nltk
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import codecs
import random
import csv

from tqdm import tqdm 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from torch.autograd import Variable
from sklearn.metrics import f1_score

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_directory = "/content/drive/My Drive/OffensEval/data/startkit/training-v1/offenseval-training-v1.tsv"
print("Reading offenseval-training-v1.tsv...")
training_data = pd.read_csv(data_directory, sep='\t', header=0)
tweets = training_data[["tweet"]]
task_a_labels = training_data[["subtask_a"]]
task_b_labels = training_data.query("subtask_a == 'OFF'")[["subtask_b"]]
task_c_labels = training_data.query("subtask_b == 'TIN'")[["subtask_c"]]
clean_tweets = copy.deepcopy(tweets)
# Out:
# Reading offenseval-training-v1.tsv...

# %%
def clean_data(tweet):
  noises = ['@USER', 'URL', '\'s', '\'ve', 'n\'t', '\'re', '\'ll', '\'d']
  for noise in noises:
    tweet = tweet.replace(noise, '')
  return re.sub(r'[^a-zA-Z]', ' ', tweet)

def tokenize(tweet):
  return word_tokenize(tweet.lower())

def remove_stop_words(tweets):
  clean_tweets = []
  stop_words = set(stopwords.words('english'))
  for tweet in tweets:
    if tweet not in stop_words:
      if tweet.replace(' ', '') != '':
        if len(tweet) > 1:
          clean_tweets.append(tweet)
  return clean_tweets

def lemmatize_and_stem(tweets):
  clean_tweets = []
  lemmatizer = WordNetLemmatizer()
  stemmer = PorterStemmer()
  for tweet in tweets:
    tweet = lemmatizer.lemmatize(tweet)
    tweet = stemmer.stem(tweet)
    if len(tweet) > 1:
      clean_tweets.append(tweet)
  return clean_tweets

def word_to_index(tweets):
  vocabulary = []
  for tweet in tweets:
    for token in tweet:
      if token not in vocabulary:
        vocabulary.append(token)
  word2index = {w: idx for (idx, w) in enumerate(vocabulary)}
  return word2index

def label_to_index(labels):
  dictionary = []
  for label in labels:
    if label not in dictionary:
      dictionary.append(label)
  label2index = {l: idx for (idx, l) in enumerate(dictionary)}
  return label2index

def tweet_to_tensor(tweets, word2index, max_len):
  vectorized_tweets = [[word2index[token] for token in tweet if token in word2index] for tweet in tweets]
  tweet_tensor = Variable(torch.zeros((len(vectorized_tweets), max_len))).long()
  tweet_lengths = [len(tweet) for tweet in vectorized_tweets]
  for index, (tweet, tweetlen) in enumerate(zip(vectorized_tweets, tweet_lengths)):
    tweet_tensor[index, :tweetlen] = torch.LongTensor(tweet)
  return tweet_tensor

def get_tensors_by_label(tensors, labels, keyword, max_len):
  if tensors.shape[0] != len(labels):
    print("Unmatching sizes")
    return
  length = labels.count(keyword)
  tweet_tensor = Variable(torch.zeros((length, max_len))).long()
  index = 0
  for tensor, label in zip(tensors, labels):
    if label == keyword:
      tweet_tensor[index] = tensor
      index += 1
  return tweet_tensor

def label_to_tensor(labels, label2index):
  vectorized_labels = [label2index[label] for label in labels if label in label2index]
  label_tensor = torch.FloatTensor(vectorized_labels)
  return label_tensor

# %%
tqdm.pandas(desc="Cleaning Data...")
clean_tweets['tweet'] = tweets['tweet'].progress_apply(clean_data)
tqdm.pandas(desc="Tokenizing Data...")
clean_tweets['tokens'] = clean_tweets['tweet'].progress_apply(tokenize)
tqdm.pandas(desc="Removing Stop Words...")
clean_tweets['tokens'] = clean_tweets['tokens'].progress_apply(remove_stop_words)
tqdm.pandas(desc="Lemmatizing And Stemming...")
clean_tweets['tokens'] = clean_tweets['tokens'].progress_apply(lemmatize_and_stem)
# Out:
# Cleaning Data...: 100%|██████████| 13240/13240 [00:00<00:00, 82996.81it/s]
# Tokenizing Data...: 100%|██████████| 13240/13240 [00:02<00:00, 5458.37it/s]
# Removing Stop Words...: 100%|██████████| 13240/13240 [00:02<00:00, 6207.36it/s]
# Lemmatizing And Stemming...: 100%|██████████| 13240/13240 [00:07<00:00, 1854.08it/s]

# %%
tokenized_tweets = clean_tweets['tokens'].tolist()

tweet_lengths = [len(tweet) for tweet in tokenized_tweets]
max_length = np.max(np.array(tweet_lengths))

word2index = word_to_index(tokenized_tweets)

labels_a = task_a_labels['subtask_a'].values.tolist()
labels_b = task_b_labels['subtask_b'].values.tolist()
labels_c = task_c_labels['subtask_c'].values.tolist()

a2index = label_to_index(labels_a)
b2index = label_to_index(labels_b)
c2index = label_to_index(labels_c)

tweets_a_tensor = tweet_to_tensor(tokenized_tweets, word2index, max_length)
tweets_b_tensor = get_tensors_by_label(tweets_a_tensor, labels_a, "OFF", max_length)
tweets_c_tensor = get_tensors_by_label(tweets_b_tensor, labels_b, "TIN", max_length)

labels_a_tensor = label_to_tensor(labels_a, a2index)
labels_b_tensor = label_to_tensor(labels_b, b2index)
labels_c_tensor = label_to_tensor(labels_c, c2index)

print("Task A tensor size:")
print(tweets_a_tensor.shape)
print("Task B tensor size:")
print(tweets_b_tensor.shape)
print("Task C tensor size:")
print(tweets_c_tensor.shape)
# Out:
# Task A tensor size:
# torch.Size([13240, 39])
# Task B tensor size:
# torch.Size([4400, 39])
# Task C tensor size:
# torch.Size([3876, 39])

# %%
def train_valid_split(dataset, labels, validation_split):
  dataset_size = dataset.shape[0]
  split = int(np.floor(validation_split * dataset_size))
  train_data = dataset[split:]
  valid_data = dataset[:split]
  train_labels = labels[split:]
  valid_labels = labels[:split]
  return train_data, valid_data, train_labels, valid_labels

def check_accuracy(output, target, num_class=2):
  if num_class == 2:
    output = torch.round(torch.sigmoid(output))
  else:
    output = F.log_softmax(output)
    output = output.data.max(1)[1].numpy()
  correct = (output == target).float()
  acc = correct.sum()/len(correct)
  return acc

def check_f1_score(output, target, num_class=2):
  if num_class == 2:
    output = torch.round(torch.sigmoid(output))
  else:
    output = F.log_softmax(output)
    output = output.data.max(1)[1].numpy()
  score = f1_score(target, output, average='macro')
  return score

# %%
class CNN(nn.Module):
    
  def __init__(self, vocab_size, embedding_dim, out_channels, window_size, output_dim, dropout):     
    super(CNN, self).__init__()
    self.embedding = nn.Embedding(vocab_size, embedding_dim)
    #in_channels -- 1 text channel
    #out_channels -- the number of output channels
    #kernel_size is (window size x embedding dim)
    self.conv = nn.Conv2d(in_channels=1, out_channels=out_channels, kernel_size=(window_size,embedding_dim))
    #the dropout layer
    self.dropout = nn.Dropout(dropout)
    #the output layer
    self.fc = nn.Linear(out_channels, output_dim)
        
  def forward(self, x):
    #(batch size, max sent length)
    embedded = self.embedding(x)
    #(batch size, max sent length, embedding dim)
    #images have 3 RGB channels 
    #for the text we add 1 channel
    embedded = embedded.unsqueeze(1)
    #(batch size, 1, max sent length, embedding dim)
    feature_maps = self.conv(embedded)
    #(batch size, n filters, max input length - window size +1)
    feature_maps = feature_maps.squeeze(3)
    feature_maps = F.relu(feature_maps)
    #the max pooling layer
    pooled = F.max_pool1d(feature_maps, feature_maps.shape[2])
    pooled = pooled.squeeze(2)
    dropped = self.dropout(pooled)
    preds = self.fc(dropped)
    return preds

# %%
class LSTMClassifier(nn.Module):
  
  def __init__(self, vocab_size, embedding_dim, hidden_dim, label_size, output_dim, dropout):
    super(LSTMClassifier, self).__init__()
    self.hidden_dim = hidden_dim
    self.embedding = nn.Embedding(vocab_size, embedding_dim)
    self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
    self.hidden2label = nn.Linear(hidden_dim, label_size)
    self.dropout_layer = nn.Dropout(dropout)
    self.fc = nn.Linear(hidden_dim, output_dim)
  
  def init_hidden(self, batch_size):
    return (Variable(torch.zeros(1, batch_size, self.hidden_dim)), Variable(torch.zeros(1, batch_size, self.hidden_dim)))
  
  def forward(self, x):
    self.hidden = self.init_hidden(x.shape[0])
    embedded = self.embedding(x)
    outputs, (ht, ct) = self.lstm(embedded, self.hidden)
    output = self.dropout_layer(ht[-1])
    preds = self.fc(output)
    return preds

# %%
def train_part(model, dataset, labels, optimizer, epochs=1, num_class=2, validation_split=0.2):
  feature_train, feature_valid, target_train, target_valid = train_valid_split(dataset, labels, validation_split)
  if num_class == 2:
    loss_fn = nn.BCEWithLogitsLoss()
  else:
    loss_fn = nn.CrossEntropyLoss()
    target_train = target_train.long()
    target_valid = target_valid.long()
  
  for e in range(1, epochs+1):
    model.train()
    optimizer.zero_grad()
    
    predictions = model(feature_train).squeeze(1)
    loss = loss_fn(predictions, target_train)
    acc = check_accuracy(predictions, target_train, num_class)
    
    loss.backward()
    optimizer.step()
    
    epoch_loss = loss.item()
    epoch_acc = acc
    
    model.eval()
    
    with torch.no_grad():
      predictions_valid = model(feature_valid).squeeze(1)
      loss = loss_fn(predictions_valid, target_valid)
      acc = check_accuracy(predictions_valid, target_valid, num_class)
      valid_loss = loss.item()
      valid_acc = acc
    
    print(f'| Epoch: {e:02} | Train Loss: {epoch_loss:.3f} | Train Acc: {epoch_acc*100:.2f}% | Val. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:.2f}% |')
    
  return valid_acc

# %%
# !pip install GPy GPyOpt

import GPy
import GPyOpt
from GPyOpt.methods import BayesianOptimization
# Out:
# Collecting GPy
#   Downloading https://files.pythonhosted.org/packages/98/7d/e55ffc3b16b68e8b50ccecacec56715bcf49d5c2f204f5ba60374d419611/GPy-1.9.6.tar.gz (873kB)
#     100% |████████████████████████████████| 880kB 21.5MB/s
# Collecting GPyOpt
#   Downloading https://files.pythonhosted.org/packages/9c/40/ca8f080d74d9f4e29069faa944fcfb083e8693b6daaba0f1e4bc65c88650/GPyOpt-1.2.5.tar.gz (55kB)
#     100% |████████████████████████████████| 61kB 20.7MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from GPy) (1.14.6)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.6/dist-packages (from GPy) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from GPy) (1.11.0)
# Collecting paramz>=0.9.0 (from GPy)
#   Downloading https://files.pythonhosted.org/packages/fd/78/b0f0164a32518bfd3b98cb2e149b7a4d5504d13fb503b31a6c59b958ed18/paramz-0.9.4.tar.gz (70kB)
#     100% |████████████████████████████████| 71kB 23.1MB/s
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.6/dist-packages (from paramz>=0.9.0->GPy) (4.3.2)
# Building wheels for collected packages: GPy, GPyOpt, paramz
#   Building wheel for GPy (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/97/82/1d/32a361e1ff2b4d9129a60343831dd99cdc74440e2db1c55264
#   Building wheel for GPyOpt (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/33/1d/87/dc02440831ba986b1547dd11a7dcd44e893b0527083066d869
#   Building wheel for paramz (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/a9/fc/74/3bbd263c43ed98d67343df24cebf0a0ee34afee40d769fda9c
# Successfully built GPy GPyOpt paramz
# Installing collected packages: paramz, GPy, GPyOpt
# Successfully installed GPy-1.9.6 GPyOpt-1.2.5 paramz-0.9.4

# %%
# Use GPyOpt for hyper-parameter search
domain = [{'name': 'embedding_dim', 'type': 'discrete', 'domain': (100, 120, 140, 160, 180, 200)},
          {'name': 'n_out_channels', 'type': 'discrete', 'domain': (100, 120, 140, 160, 180, 200)},
          {'name': 'hidden_dim', 'type': 'discrete', 'domain': (32, 64, 96, 128)},
          {'name': 'drop_out', 'type': 'continuous', 'domain': (0.2, 0.5)},
          {'name': 'lr', 'type': 'continuous', 'domain': (0.0001, 0.01)},
          {'name': 'momentum', 'type': 'continuous', 'domain': (0.5, 0.9)}
         ]

# %%
INPUT_DIM = len(word2index)
OUTPUT_DIM = 1

# window size
WINDOW_SIZE = 1

def taskA_tuning(params):
  param = params[0]
  # CNN(vocab_size, embedding_dim, out_channels, window_size, output_dim, dropout)
  # model = CNN(INPUT_DIM, int(param[0]), int(param[1]), WINDOW_SIZE, OUTPUT_DIM, param[3])
  # LSTMClassifier(vocab_size, embedding_dim, hidden_dim, label_size, output_dim, dropout)
  model = LSTMClassifier(INPUT_DIM, int(param[0]), int(param[2]), 2, OUTPUT_DIM, param[3])
  optimizer = optim.SGD(model.parameters(), lr=param[4], momentum=param[5])
  acc = train_part(model, tweets_a_tensor, labels_a_tensor, optimizer, epochs=10)
  return acc

taskA_opt = BayesianOptimization(f=taskA_tuning,
                                 domain=domain,
                                 model_type='GP',
                                 acquisition_type='EI',
                                 acquisition_jitter=0.05,
                                 maximize=True)

taskA_opt.run_optimization(max_iter=20)
# Out:
# | Epoch: 01 | Train Loss: 0.728 | Train Acc: 33.23% | Val. Loss: 0.724 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.726 | Train Acc: 33.36% | Val. Loss: 0.720 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.720 | Train Acc: 33.87% | Val. Loss: 0.714 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.715 | Train Acc: 34.87% | Val. Loss: 0.707 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.708 | Train Acc: 36.93% | Val. Loss: 0.700 | Val. Acc: 33.57% |
# | Epoch: 06 | Train Loss: 0.701 | Train Acc: 42.10% | Val. Loss: 0.694 | Val. Acc: 33.72% |
# | Epoch: 07 | Train Loss: 0.694 | Train Acc: 50.16% | Val. Loss: 0.687 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.687 | Train Acc: 57.23% | Val. Loss: 0.681 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.681 | Train Acc: 62.74% | Val. Loss: 0.676 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.676 | Train Acc: 65.00% | Val. Loss: 0.671 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.673 | Train Acc: 64.95% | Val. Loss: 0.670 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.671 | Train Acc: 65.48% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.667 | Train Acc: 66.34% | Val. Loss: 0.662 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.662 | Train Acc: 66.76% | Val. Loss: 0.658 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.658 | Train Acc: 66.81% | Val. Loss: 0.655 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.655 | Train Acc: 66.85% | Val. Loss: 0.652 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.652 | Train Acc: 66.84% | Val. Loss: 0.649 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.649 | Train Acc: 66.85% | Val. Loss: 0.647 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.647 | Train Acc: 66.85% | Val. Loss: 0.646 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.645 | Train Acc: 66.84% | Val. Loss: 0.644 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.703 | Train Acc: 46.07% | Val. Loss: 0.699 | Val. Acc: 33.53% |
# | Epoch: 02 | Train Loss: 0.702 | Train Acc: 46.43% | Val. Loss: 0.695 | Val. Acc: 33.53% |
# | Epoch: 03 | Train Loss: 0.696 | Train Acc: 49.07% | Val. Loss: 0.690 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.693 | Train Acc: 51.76% | Val. Loss: 0.685 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.687 | Train Acc: 54.52% | Val. Loss: 0.680 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.682 | Train Acc: 57.73% | Val. Loss: 0.675 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.676 | Train Acc: 61.16% | Val. Loss: 0.671 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.673 | Train Acc: 62.50% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.668 | Train Acc: 64.06% | Val. Loss: 0.662 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.664 | Train Acc: 65.02% | Val. Loss: 0.659 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.665 | Train Acc: 64.34% | Val. Loss: 0.663 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.665 | Train Acc: 65.53% | Val. Loss: 0.661 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.663 | Train Acc: 65.39% | Val. Loss: 0.659 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.661 | Train Acc: 65.86% | Val. Loss: 0.657 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.660 | Train Acc: 66.22% | Val. Loss: 0.655 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.656 | Train Acc: 66.55% | Val. Loss: 0.653 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.652 | Train Acc: 66.65% | Val. Loss: 0.650 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.651 | Train Acc: 66.69% | Val. Loss: 0.648 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.649 | Train Acc: 66.75% | Val. Loss: 0.647 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.647 | Train Acc: 66.82% | Val. Loss: 0.645 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.743 | Train Acc: 35.68% | Val. Loss: 0.737 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.739 | Train Acc: 36.09% | Val. Loss: 0.732 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.737 | Train Acc: 36.23% | Val. Loss: 0.728 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.731 | Train Acc: 37.02% | Val. Loss: 0.723 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.725 | Train Acc: 38.70% | Val. Loss: 0.718 | Val. Acc: 33.57% |
# | Epoch: 06 | Train Loss: 0.721 | Train Acc: 39.55% | Val. Loss: 0.713 | Val. Acc: 33.57% |
# | Epoch: 07 | Train Loss: 0.716 | Train Acc: 41.81% | Val. Loss: 0.708 | Val. Acc: 33.57% |
# | Epoch: 08 | Train Loss: 0.712 | Train Acc: 42.63% | Val. Loss: 0.704 | Val. Acc: 33.53% |
# | Epoch: 09 | Train Loss: 0.707 | Train Acc: 44.72% | Val. Loss: 0.700 | Val. Acc: 33.53% |
# | Epoch: 10 | Train Loss: 0.704 | Train Acc: 45.86% | Val. Loss: 0.696 | Val. Acc: 33.50% |
# | Epoch: 01 | Train Loss: 0.711 | Train Acc: 35.47% | Val. Loss: 0.705 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.705 | Train Acc: 38.73% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.697 | Train Acc: 45.95% | Val. Loss: 0.688 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.688 | Train Acc: 56.11% | Val. Loss: 0.679 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.679 | Train Acc: 63.74% | Val. Loss: 0.671 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.670 | Train Acc: 66.07% | Val. Loss: 0.664 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.663 | Train Acc: 66.82% | Val. Loss: 0.658 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.657 | Train Acc: 66.82% | Val. Loss: 0.653 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.653 | Train Acc: 66.85% | Val. Loss: 0.649 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.648 | Train Acc: 66.85% | Val. Loss: 0.646 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.730 | Train Acc: 33.52% | Val. Loss: 0.726 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.728 | Train Acc: 33.56% | Val. Loss: 0.724 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.725 | Train Acc: 33.65% | Val. Loss: 0.721 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.722 | Train Acc: 34.12% | Val. Loss: 0.717 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.719 | Train Acc: 34.96% | Val. Loss: 0.714 | Val. Acc: 33.57% |
# | Epoch: 06 | Train Loss: 0.716 | Train Acc: 35.65% | Val. Loss: 0.711 | Val. Acc: 33.57% |
# | Epoch: 07 | Train Loss: 0.713 | Train Acc: 36.65% | Val. Loss: 0.708 | Val. Acc: 33.57% |
# | Epoch: 08 | Train Loss: 0.709 | Train Acc: 38.74% | Val. Loss: 0.705 | Val. Acc: 33.57% |
# | Epoch: 09 | Train Loss: 0.706 | Train Acc: 40.48% | Val. Loss: 0.703 | Val. Acc: 33.57% |
# | Epoch: 10 | Train Loss: 0.704 | Train Acc: 42.09% | Val. Loss: 0.700 | Val. Acc: 33.57% |
# | Epoch: 01 | Train Loss: 0.714 | Train Acc: 37.08% | Val. Loss: 0.710 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.711 | Train Acc: 38.53% | Val. Loss: 0.705 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.706 | Train Acc: 41.04% | Val. Loss: 0.699 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.701 | Train Acc: 45.41% | Val. Loss: 0.693 | Val. Acc: 66.54% |
# | Epoch: 05 | Train Loss: 0.694 | Train Acc: 50.51% | Val. Loss: 0.687 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.687 | Train Acc: 56.17% | Val. Loss: 0.681 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.681 | Train Acc: 60.67% | Val. Loss: 0.675 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.676 | Train Acc: 63.09% | Val. Loss: 0.670 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.670 | Train Acc: 65.60% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.666 | Train Acc: 66.04% | Val. Loss: 0.661 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.737 | Train Acc: 36.87% | Val. Loss: 0.732 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.736 | Train Acc: 37.08% | Val. Loss: 0.731 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.735 | Train Acc: 37.07% | Val. Loss: 0.729 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.734 | Train Acc: 37.48% | Val. Loss: 0.728 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.731 | Train Acc: 37.87% | Val. Loss: 0.727 | Val. Acc: 33.57% |
# | Epoch: 06 | Train Loss: 0.731 | Train Acc: 37.83% | Val. Loss: 0.725 | Val. Acc: 33.57% |
# | Epoch: 07 | Train Loss: 0.730 | Train Acc: 38.51% | Val. Loss: 0.724 | Val. Acc: 33.57% |
# | Epoch: 08 | Train Loss: 0.728 | Train Acc: 39.06% | Val. Loss: 0.723 | Val. Acc: 33.57% |
# | Epoch: 09 | Train Loss: 0.727 | Train Acc: 38.91% | Val. Loss: 0.721 | Val. Acc: 33.57% |
# | Epoch: 10 | Train Loss: 0.725 | Train Acc: 39.54% | Val. Loss: 0.720 | Val. Acc: 33.57% |
# | Epoch: 01 | Train Loss: 0.678 | Train Acc: 61.50% | Val. Loss: 0.675 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.677 | Train Acc: 62.24% | Val. Loss: 0.672 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.673 | Train Acc: 63.47% | Val. Loss: 0.668 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.669 | Train Acc: 65.13% | Val. Loss: 0.664 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.665 | Train Acc: 65.82% | Val. Loss: 0.660 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.661 | Train Acc: 66.40% | Val. Loss: 0.657 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.658 | Train Acc: 66.57% | Val. Loss: 0.654 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.654 | Train Acc: 66.76% | Val. Loss: 0.651 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.651 | Train Acc: 66.80% | Val. Loss: 0.648 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.649 | Train Acc: 66.81% | Val. Loss: 0.646 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.698 | Train Acc: 48.25% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.699 | Train Acc: 46.75% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.699 | Train Acc: 47.53% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.699 | Train Acc: 46.97% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.698 | Train Acc: 48.03% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 06 | Train Loss: 0.699 | Train Acc: 47.27% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 07 | Train Loss: 0.699 | Train Acc: 46.96% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 08 | Train Loss: 0.698 | Train Acc: 47.53% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 09 | Train Loss: 0.698 | Train Acc: 47.60% | Val. Loss: 0.696 | Val. Acc: 33.57% |
# | Epoch: 10 | Train Loss: 0.698 | Train Acc: 47.52% | Val. Loss: 0.696 | Val. Acc: 33.57% |
# | Epoch: 01 | Train Loss: 0.678 | Train Acc: 60.70% | Val. Loss: 0.674 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.675 | Train Acc: 62.53% | Val. Loss: 0.670 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.671 | Train Acc: 63.90% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.667 | Train Acc: 64.78% | Val. Loss: 0.661 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.661 | Train Acc: 66.12% | Val. Loss: 0.657 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.657 | Train Acc: 66.31% | Val. Loss: 0.653 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.653 | Train Acc: 66.78% | Val. Loss: 0.650 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.650 | Train Acc: 66.81% | Val. Loss: 0.647 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.646 | Train Acc: 66.76% | Val. Loss: 0.645 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.644 | Train Acc: 66.84% | Val. Loss: 0.643 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.670 | Train Acc: 64.24% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.667 | Train Acc: 65.24% | Val. Loss: 0.663 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.665 | Train Acc: 66.12% | Val. Loss: 0.659 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.659 | Train Acc: 66.38% | Val. Loss: 0.655 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.655 | Train Acc: 66.76% | Val. Loss: 0.650 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.651 | Train Acc: 66.81% | Val. Loss: 0.647 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.647 | Train Acc: 66.80% | Val. Loss: 0.644 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.644 | Train Acc: 66.84% | Val. Loss: 0.642 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.642 | Train Acc: 66.85% | Val. Loss: 0.640 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.640 | Train Acc: 66.84% | Val. Loss: 0.639 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.703 | Train Acc: 45.75% | Val. Loss: 0.694 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.695 | Train Acc: 50.25% | Val. Loss: 0.683 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.683 | Train Acc: 57.19% | Val. Loss: 0.670 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.672 | Train Acc: 62.63% | Val. Loss: 0.658 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.658 | Train Acc: 66.15% | Val. Loss: 0.648 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.650 | Train Acc: 66.76% | Val. Loss: 0.642 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.642 | Train Acc: 66.85% | Val. Loss: 0.638 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.638 | Train Acc: 66.84% | Val. Loss: 0.638 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.639 | Train Acc: 66.85% | Val. Loss: 0.640 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.640 | Train Acc: 66.85% | Val. Loss: 0.643 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.691 | Train Acc: 53.03% | Val. Loss: 0.686 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.686 | Train Acc: 57.39% | Val. Loss: 0.678 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.679 | Train Acc: 62.53% | Val. Loss: 0.671 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.671 | Train Acc: 65.70% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.665 | Train Acc: 66.40% | Val. Loss: 0.659 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.659 | Train Acc: 66.85% | Val. Loss: 0.655 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.655 | Train Acc: 66.86% | Val. Loss: 0.651 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.651 | Train Acc: 66.83% | Val. Loss: 0.649 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.648 | Train Acc: 66.84% | Val. Loss: 0.646 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.646 | Train Acc: 66.84% | Val. Loss: 0.645 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.717 | Train Acc: 34.61% | Val. Loss: 0.712 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.712 | Train Acc: 36.05% | Val. Loss: 0.704 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.705 | Train Acc: 39.99% | Val. Loss: 0.693 | Val. Acc: 33.61% |
# | Epoch: 04 | Train Loss: 0.694 | Train Acc: 50.25% | Val. Loss: 0.682 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.682 | Train Acc: 60.97% | Val. Loss: 0.671 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.671 | Train Acc: 65.79% | Val. Loss: 0.661 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.660 | Train Acc: 66.76% | Val. Loss: 0.652 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.652 | Train Acc: 66.83% | Val. Loss: 0.646 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.645 | Train Acc: 66.85% | Val. Loss: 0.641 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.640 | Train Acc: 66.85% | Val. Loss: 0.639 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.724 | Train Acc: 37.77% | Val. Loss: 0.722 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.725 | Train Acc: 37.25% | Val. Loss: 0.721 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.724 | Train Acc: 37.01% | Val. Loss: 0.721 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.724 | Train Acc: 38.18% | Val. Loss: 0.721 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.724 | Train Acc: 37.42% | Val. Loss: 0.721 | Val. Acc: 33.57% |
# | Epoch: 06 | Train Loss: 0.723 | Train Acc: 37.83% | Val. Loss: 0.720 | Val. Acc: 33.57% |
# | Epoch: 07 | Train Loss: 0.723 | Train Acc: 37.89% | Val. Loss: 0.720 | Val. Acc: 33.57% |
# | Epoch: 08 | Train Loss: 0.723 | Train Acc: 38.08% | Val. Loss: 0.719 | Val. Acc: 33.57% |
# | Epoch: 09 | Train Loss: 0.723 | Train Acc: 37.42% | Val. Loss: 0.719 | Val. Acc: 33.57% |
# | Epoch: 10 | Train Loss: 0.722 | Train Acc: 37.97% | Val. Loss: 0.719 | Val. Acc: 33.57% |
# | Epoch: 01 | Train Loss: 0.713 | Train Acc: 34.88% | Val. Loss: 0.707 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.707 | Train Acc: 37.80% | Val. Loss: 0.699 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.699 | Train Acc: 44.44% | Val. Loss: 0.690 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.690 | Train Acc: 54.18% | Val. Loss: 0.681 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.682 | Train Acc: 62.22% | Val. Loss: 0.673 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.673 | Train Acc: 65.73% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.666 | Train Acc: 66.77% | Val. Loss: 0.660 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.660 | Train Acc: 66.81% | Val. Loss: 0.656 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.655 | Train Acc: 66.85% | Val. Loss: 0.652 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.651 | Train Acc: 66.85% | Val. Loss: 0.649 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.735 | Train Acc: 36.47% | Val. Loss: 0.730 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.735 | Train Acc: 36.76% | Val. Loss: 0.727 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.732 | Train Acc: 37.18% | Val. Loss: 0.724 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.727 | Train Acc: 38.66% | Val. Loss: 0.719 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.724 | Train Acc: 39.12% | Val. Loss: 0.714 | Val. Acc: 33.57% |
# | Epoch: 06 | Train Loss: 0.716 | Train Acc: 42.20% | Val. Loss: 0.708 | Val. Acc: 33.57% |
# | Epoch: 07 | Train Loss: 0.712 | Train Acc: 43.29% | Val. Loss: 0.702 | Val. Acc: 33.57% |
# | Epoch: 08 | Train Loss: 0.705 | Train Acc: 46.03% | Val. Loss: 0.696 | Val. Acc: 33.57% |
# | Epoch: 09 | Train Loss: 0.699 | Train Acc: 48.01% | Val. Loss: 0.690 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.691 | Train Acc: 52.62% | Val. Loss: 0.684 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.681 | Train Acc: 61.27% | Val. Loss: 0.676 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.676 | Train Acc: 64.22% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.668 | Train Acc: 66.12% | Val. Loss: 0.658 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.658 | Train Acc: 66.81% | Val. Loss: 0.649 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.649 | Train Acc: 66.84% | Val. Loss: 0.643 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.642 | Train Acc: 66.84% | Val. Loss: 0.639 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.638 | Train Acc: 66.84% | Val. Loss: 0.638 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.637 | Train Acc: 66.84% | Val. Loss: 0.639 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.637 | Train Acc: 66.84% | Val. Loss: 0.640 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.637 | Train Acc: 66.84% | Val. Loss: 0.642 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.728 | Train Acc: 35.26% | Val. Loss: 0.726 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.729 | Train Acc: 35.35% | Val. Loss: 0.726 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.730 | Train Acc: 35.00% | Val. Loss: 0.726 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.729 | Train Acc: 35.08% | Val. Loss: 0.726 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.728 | Train Acc: 35.48% | Val. Loss: 0.725 | Val. Acc: 33.57% |
# | Epoch: 06 | Train Loss: 0.727 | Train Acc: 35.51% | Val. Loss: 0.725 | Val. Acc: 33.57% |
# | Epoch: 07 | Train Loss: 0.728 | Train Acc: 35.36% | Val. Loss: 0.725 | Val. Acc: 33.57% |
# | Epoch: 08 | Train Loss: 0.727 | Train Acc: 35.56% | Val. Loss: 0.724 | Val. Acc: 33.57% |
# | Epoch: 09 | Train Loss: 0.727 | Train Acc: 35.92% | Val. Loss: 0.724 | Val. Acc: 33.57% |
# | Epoch: 10 | Train Loss: 0.727 | Train Acc: 36.05% | Val. Loss: 0.724 | Val. Acc: 33.57% |
# | Epoch: 01 | Train Loss: 0.739 | Train Acc: 33.18% | Val. Loss: 0.731 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.732 | Train Acc: 33.29% | Val. Loss: 0.721 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.722 | Train Acc: 33.84% | Val. Loss: 0.711 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.712 | Train Acc: 35.53% | Val. Loss: 0.701 | Val. Acc: 33.57% |
# | Epoch: 05 | Train Loss: 0.703 | Train Acc: 41.30% | Val. Loss: 0.692 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.693 | Train Acc: 50.45% | Val. Loss: 0.685 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.685 | Train Acc: 59.63% | Val. Loss: 0.678 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.678 | Train Acc: 64.15% | Val. Loss: 0.672 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.672 | Train Acc: 65.97% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.668 | Train Acc: 66.64% | Val. Loss: 0.663 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.664 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.663 | Train Acc: 66.84% | Val. Loss: 0.661 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.660 | Train Acc: 66.85% | Val. Loss: 0.659 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.658 | Train Acc: 66.84% | Val. Loss: 0.656 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.655 | Train Acc: 66.85% | Val. Loss: 0.653 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.652 | Train Acc: 66.84% | Val. Loss: 0.650 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.649 | Train Acc: 66.85% | Val. Loss: 0.648 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.647 | Train Acc: 66.85% | Val. Loss: 0.646 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.645 | Train Acc: 66.85% | Val. Loss: 0.644 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.643 | Train Acc: 66.85% | Val. Loss: 0.643 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.726 | Train Acc: 37.67% | Val. Loss: 0.717 | Val. Acc: 33.57% |
# | Epoch: 02 | Train Loss: 0.721 | Train Acc: 39.03% | Val. Loss: 0.708 | Val. Acc: 33.57% |
# | Epoch: 03 | Train Loss: 0.711 | Train Acc: 42.85% | Val. Loss: 0.697 | Val. Acc: 33.57% |
# | Epoch: 04 | Train Loss: 0.698 | Train Acc: 48.65% | Val. Loss: 0.685 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.687 | Train Acc: 54.93% | Val. Loss: 0.673 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.675 | Train Acc: 61.54% | Val. Loss: 0.662 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.664 | Train Acc: 65.12% | Val. Loss: 0.653 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.655 | Train Acc: 66.39% | Val. Loss: 0.647 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.648 | Train Acc: 66.76% | Val. Loss: 0.642 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.643 | Train Acc: 66.82% | Val. Loss: 0.640 | Val. Acc: 66.43% |
# | Epoch: 01 | Train Loss: 0.683 | Train Acc: 59.95% | Val. Loss: 0.683 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.683 | Train Acc: 59.76% | Val. Loss: 0.683 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.683 | Train Acc: 59.95% | Val. Loss: 0.683 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.683 | Train Acc: 59.70% | Val. Loss: 0.682 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.683 | Train Acc: 59.86% | Val. Loss: 0.682 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.682 | Train Acc: 60.31% | Val. Loss: 0.682 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.683 | Train Acc: 59.68% | Val. Loss: 0.682 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.682 | Train Acc: 60.13% | Val. Loss: 0.682 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.682 | Train Acc: 60.30% | Val. Loss: 0.681 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.683 | Train Acc: 59.99% | Val. Loss: 0.681 | Val. Acc: 66.43% |

# %%
print("The hyperparameters used for the model in task A are")
print(f'embedding_dim: {int(taskA_opt.X[-1][0])}')
print(f'hidden_dim: {int(taskA_opt.X[-1][2])}')
print(f'drop_out: {taskA_opt.X[-1][3]:.2f}')
print(f'learning_rate: {taskA_opt.X[-1][4]:.4f}')
print(f'weight_decay: {taskA_opt.X[-1][5]:.4f}')
# Out:
# The hyperparameters used for the model in task A are
# embedding_dim: 100
# hidden_dim: 32
# drop_out: 0.20
# learning_rate: 0.0001
# weight_decay: 0.9000

# %%
# CNN(vocab_size, embedding_dim, out_channels, window_size, output_dim, dropout)
# test_model_A = CNN(INPUT_DIM, int(taskA_opt.X[-1][0]), int(taskA_opt.X[-1][1]), WINDOW_SIZE, OUTPUT_DIM, taskA_opt.X[-1][3])
# LSTMClassifier(vocab_size, embedding_dim, hidden_dim, label_size, output_dim, dropout)
test_model_A = LSTMClassifier(INPUT_DIM, int(taskA_opt.X[-1][0]), int(taskA_opt.X[-1][2]), 2, OUTPUT_DIM, int(taskA_opt.X[-1][3]))
optimizer_A = optim.SGD(test_model_A.parameters(), lr=taskA_opt.X[-1][4], momentum=taskA_opt.X[-1][5])
train_part(test_model_A, tweets_a_tensor, labels_a_tensor, optimizer_A, epochs=50)
# Out:
# | Epoch: 01 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.668 | Val. Acc: 66.43% |
# | Epoch: 02 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.668 | Val. Acc: 66.43% |
# | Epoch: 03 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.668 | Val. Acc: 66.43% |
# | Epoch: 04 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.668 | Val. Acc: 66.43% |
# | Epoch: 05 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 06 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 07 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 08 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 09 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 10 | Train Loss: 0.667 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 11 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 12 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 13 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 14 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 15 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 16 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 17 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 18 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 19 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 20 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 21 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.667 | Val. Acc: 66.43% |
# | Epoch: 22 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 23 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 24 | Train Loss: 0.666 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 25 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 26 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 27 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 28 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 29 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 30 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 31 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 32 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 33 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 34 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.666 | Val. Acc: 66.43% |
# | Epoch: 35 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 36 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 37 | Train Loss: 0.665 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 38 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 39 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 40 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 41 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 42 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 43 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 44 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 45 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 46 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.665 | Val. Acc: 66.43% |
# | Epoch: 47 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.664 | Val. Acc: 66.43% |
# | Epoch: 48 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.664 | Val. Acc: 66.43% |
# | Epoch: 49 | Train Loss: 0.664 | Train Acc: 66.84% | Val. Loss: 0.664 | Val. Acc: 66.43% |
# | Epoch: 50 | Train Loss: 0.663 | Train Acc: 66.84% | Val. Loss: 0.664 | Val. Acc: 66.43% |
# tensor(0.6643)

# %%
_, feature_valid, _, target_valid = train_valid_split(tweets_a_tensor, labels_a_tensor, 0.2)

test_model_A.eval()

with torch.no_grad():
  predictions = test_model_A(feature_valid).squeeze(1)
  acc = check_accuracy(predictions, target_valid)
  score = check_f1_score(predictions, target_valid)

print(f'Validation Accuracy: {acc:.4f}')
print(f'Validation F1 Score: {score:.4f}')
# Out:
# Validation Accuracy: 0.6643
# Validation F1 Score: 0.3991

# %%
INPUT_DIM = len(word2index)
OUTPUT_DIM = 1

# window size
WINDOW_SIZE = 1

def taskB_tuning(params):
  param = params[0]
  # CNN(vocab_size, embedding_dim, out_channels, window_size, output_dim, dropout)
  # model = CNN(INPUT_DIM, int(param[0]), int(param[1]), WINDOW_SIZE, OUTPUT_DIM, param[3])
  # LSTMClassifier(vocab_size, embedding_dim, hidden_dim, label_size, output_dim, dropout)
  model = LSTMClassifier(INPUT_DIM, int(param[0]), int(param[2]), 2, OUTPUT_DIM, param[3])
  optimizer = optim.SGD(model.parameters(), lr=param[4], momentum=param[5])
  acc = train_part(model, tweets_b_tensor, labels_b_tensor, optimizer, epochs=10)
  return acc

taskB_opt = BayesianOptimization(f=taskB_tuning,
                                 domain=domain,
                                 model_type='GP',
                                 acquisition_type='EI',
                                 acquisition_jitter=0.05,
                                 maximize=True)

taskB_opt.run_optimization(max_iter=20)
# Out:
# | Epoch: 01 | Train Loss: 0.616 | Train Acc: 86.28% | Val. Loss: 0.600 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.606 | Train Acc: 87.16% | Val. Loss: 0.585 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.590 | Train Acc: 87.67% | Val. Loss: 0.568 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.576 | Train Acc: 87.61% | Val. Loss: 0.552 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.560 | Train Acc: 87.70% | Val. Loss: 0.536 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.546 | Train Acc: 87.73% | Val. Loss: 0.522 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.533 | Train Acc: 87.76% | Val. Loss: 0.510 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.520 | Train Acc: 87.76% | Val. Loss: 0.498 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.511 | Train Acc: 87.76% | Val. Loss: 0.488 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.500 | Train Acc: 87.76% | Val. Loss: 0.479 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.647 | Train Acc: 76.68% | Val. Loss: 0.639 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.646 | Train Acc: 77.44% | Val. Loss: 0.636 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.642 | Train Acc: 78.75% | Val. Loss: 0.631 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.636 | Train Acc: 80.43% | Val. Loss: 0.626 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.628 | Train Acc: 82.50% | Val. Loss: 0.621 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.625 | Train Acc: 83.64% | Val. Loss: 0.615 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.620 | Train Acc: 84.35% | Val. Loss: 0.609 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.615 | Train Acc: 84.89% | Val. Loss: 0.604 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.610 | Train Acc: 85.80% | Val. Loss: 0.598 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.605 | Train Acc: 85.99% | Val. Loss: 0.593 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.639 | Train Acc: 82.90% | Val. Loss: 0.632 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.636 | Train Acc: 83.38% | Val. Loss: 0.629 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.633 | Train Acc: 84.29% | Val. Loss: 0.625 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.629 | Train Acc: 84.86% | Val. Loss: 0.620 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.625 | Train Acc: 85.60% | Val. Loss: 0.615 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.620 | Train Acc: 86.16% | Val. Loss: 0.610 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.615 | Train Acc: 86.42% | Val. Loss: 0.605 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.609 | Train Acc: 86.99% | Val. Loss: 0.600 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.605 | Train Acc: 87.16% | Val. Loss: 0.595 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.601 | Train Acc: 87.30% | Val. Loss: 0.590 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.669 | Train Acc: 69.23% | Val. Loss: 0.663 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.666 | Train Acc: 70.68% | Val. Loss: 0.657 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.659 | Train Acc: 74.66% | Val. Loss: 0.651 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.653 | Train Acc: 77.22% | Val. Loss: 0.643 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.647 | Train Acc: 79.86% | Val. Loss: 0.636 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.640 | Train Acc: 81.79% | Val. Loss: 0.629 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.634 | Train Acc: 82.64% | Val. Loss: 0.622 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.626 | Train Acc: 84.15% | Val. Loss: 0.615 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.621 | Train Acc: 84.94% | Val. Loss: 0.609 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.614 | Train Acc: 85.97% | Val. Loss: 0.603 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.729 | Train Acc: 20.54% | Val. Loss: 0.720 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.721 | Train Acc: 25.00% | Val. Loss: 0.705 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.705 | Train Acc: 38.15% | Val. Loss: 0.687 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.688 | Train Acc: 56.62% | Val. Loss: 0.667 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.669 | Train Acc: 74.01% | Val. Loss: 0.648 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.650 | Train Acc: 83.49% | Val. Loss: 0.628 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.632 | Train Acc: 86.65% | Val. Loss: 0.610 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.614 | Train Acc: 87.64% | Val. Loss: 0.592 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.597 | Train Acc: 87.73% | Val. Loss: 0.576 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.583 | Train Acc: 87.76% | Val. Loss: 0.560 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.833 | Train Acc: 12.30% | Val. Loss: 0.806 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.803 | Train Acc: 12.36% | Val. Loss: 0.756 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.754 | Train Acc: 15.40% | Val. Loss: 0.696 | Val. Acc: 10.68% |
# | Epoch: 04 | Train Loss: 0.697 | Train Acc: 47.78% | Val. Loss: 0.636 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.640 | Train Acc: 83.69% | Val. Loss: 0.580 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.586 | Train Acc: 87.70% | Val. Loss: 0.532 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.539 | Train Acc: 87.76% | Val. Loss: 0.492 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.504 | Train Acc: 87.76% | Val. Loss: 0.461 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.475 | Train Acc: 87.76% | Val. Loss: 0.436 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.451 | Train Acc: 87.76% | Val. Loss: 0.417 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.724 | Train Acc: 35.03% | Val. Loss: 0.695 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.698 | Train Acc: 48.72% | Val. Loss: 0.652 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.652 | Train Acc: 72.95% | Val. Loss: 0.605 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.612 | Train Acc: 83.78% | Val. Loss: 0.560 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.569 | Train Acc: 87.27% | Val. Loss: 0.520 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.529 | Train Acc: 87.76% | Val. Loss: 0.486 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.500 | Train Acc: 87.76% | Val. Loss: 0.458 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.473 | Train Acc: 87.76% | Val. Loss: 0.435 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.452 | Train Acc: 87.76% | Val. Loss: 0.416 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.437 | Train Acc: 87.76% | Val. Loss: 0.401 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.548 | Train Acc: 87.76% | Val. Loss: 0.536 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.545 | Train Acc: 87.76% | Val. Loss: 0.532 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.542 | Train Acc: 87.76% | Val. Loss: 0.526 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.535 | Train Acc: 87.76% | Val. Loss: 0.519 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.530 | Train Acc: 87.76% | Val. Loss: 0.511 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.522 | Train Acc: 87.76% | Val. Loss: 0.503 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.515 | Train Acc: 87.76% | Val. Loss: 0.495 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.507 | Train Acc: 87.76% | Val. Loss: 0.486 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.499 | Train Acc: 87.76% | Val. Loss: 0.478 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.491 | Train Acc: 87.76% | Val. Loss: 0.470 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.689 | Train Acc: 53.44% | Val. Loss: 0.674 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.675 | Train Acc: 61.16% | Val. Loss: 0.654 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.658 | Train Acc: 68.72% | Val. Loss: 0.632 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.636 | Train Acc: 77.44% | Val. Loss: 0.609 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.616 | Train Acc: 82.05% | Val. Loss: 0.586 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.594 | Train Acc: 85.85% | Val. Loss: 0.565 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.573 | Train Acc: 87.33% | Val. Loss: 0.546 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.555 | Train Acc: 87.56% | Val. Loss: 0.529 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.541 | Train Acc: 87.76% | Val. Loss: 0.514 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.529 | Train Acc: 87.76% | Val. Loss: 0.500 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.765 | Train Acc: 15.91% | Val. Loss: 0.749 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.748 | Train Acc: 19.89% | Val. Loss: 0.720 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.720 | Train Acc: 31.88% | Val. Loss: 0.684 | Val. Acc: 89.32% |
# | Epoch: 04 | Train Loss: 0.687 | Train Acc: 54.80% | Val. Loss: 0.646 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.649 | Train Acc: 79.60% | Val. Loss: 0.608 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.615 | Train Acc: 86.22% | Val. Loss: 0.572 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.580 | Train Acc: 87.61% | Val. Loss: 0.540 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.549 | Train Acc: 87.76% | Val. Loss: 0.510 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.521 | Train Acc: 87.76% | Val. Loss: 0.485 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.498 | Train Acc: 87.76% | Val. Loss: 0.462 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.759 | Train Acc: 14.91% | Val. Loss: 0.746 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.744 | Train Acc: 18.35% | Val. Loss: 0.723 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.723 | Train Acc: 27.61% | Val. Loss: 0.697 | Val. Acc: 10.68% |
# | Epoch: 04 | Train Loss: 0.699 | Train Acc: 45.51% | Val. Loss: 0.671 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.673 | Train Acc: 68.04% | Val. Loss: 0.646 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.650 | Train Acc: 80.85% | Val. Loss: 0.623 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.628 | Train Acc: 85.88% | Val. Loss: 0.601 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.607 | Train Acc: 87.44% | Val. Loss: 0.581 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.587 | Train Acc: 87.61% | Val. Loss: 0.563 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.571 | Train Acc: 87.76% | Val. Loss: 0.547 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.600 | Train Acc: 85.74% | Val. Loss: 0.589 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.597 | Train Acc: 85.80% | Val. Loss: 0.584 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.590 | Train Acc: 86.88% | Val. Loss: 0.579 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.589 | Train Acc: 86.25% | Val. Loss: 0.574 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.581 | Train Acc: 87.05% | Val. Loss: 0.568 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.577 | Train Acc: 86.90% | Val. Loss: 0.563 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.571 | Train Acc: 87.24% | Val. Loss: 0.557 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.567 | Train Acc: 87.36% | Val. Loss: 0.552 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.562 | Train Acc: 87.33% | Val. Loss: 0.547 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.556 | Train Acc: 87.50% | Val. Loss: 0.542 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.658 | Train Acc: 80.14% | Val. Loss: 0.629 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.633 | Train Acc: 86.88% | Val. Loss: 0.586 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.591 | Train Acc: 87.76% | Val. Loss: 0.537 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.546 | Train Acc: 87.76% | Val. Loss: 0.491 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.501 | Train Acc: 87.76% | Val. Loss: 0.452 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.467 | Train Acc: 87.76% | Val. Loss: 0.422 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.439 | Train Acc: 87.76% | Val. Loss: 0.399 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.420 | Train Acc: 87.76% | Val. Loss: 0.382 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.405 | Train Acc: 87.76% | Val. Loss: 0.370 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.394 | Train Acc: 87.76% | Val. Loss: 0.361 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.790 | Train Acc: 13.35% | Val. Loss: 0.786 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.785 | Train Acc: 13.61% | Val. Loss: 0.776 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.775 | Train Acc: 14.15% | Val. Loss: 0.762 | Val. Acc: 10.57% |
# | Epoch: 04 | Train Loss: 0.760 | Train Acc: 16.88% | Val. Loss: 0.747 | Val. Acc: 10.57% |
# | Epoch: 05 | Train Loss: 0.746 | Train Acc: 20.20% | Val. Loss: 0.731 | Val. Acc: 10.57% |
# | Epoch: 06 | Train Loss: 0.730 | Train Acc: 26.76% | Val. Loss: 0.714 | Val. Acc: 10.57% |
# | Epoch: 07 | Train Loss: 0.716 | Train Acc: 35.11% | Val. Loss: 0.698 | Val. Acc: 10.80% |
# | Epoch: 08 | Train Loss: 0.698 | Train Acc: 48.32% | Val. Loss: 0.682 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.684 | Train Acc: 58.38% | Val. Loss: 0.666 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.668 | Train Acc: 69.69% | Val. Loss: 0.652 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.692 | Train Acc: 51.36% | Val. Loss: 0.688 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.689 | Train Acc: 53.52% | Val. Loss: 0.683 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.687 | Train Acc: 55.51% | Val. Loss: 0.678 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.682 | Train Acc: 58.49% | Val. Loss: 0.673 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.675 | Train Acc: 63.10% | Val. Loss: 0.667 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.670 | Train Acc: 66.19% | Val. Loss: 0.662 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.665 | Train Acc: 69.23% | Val. Loss: 0.656 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.660 | Train Acc: 71.96% | Val. Loss: 0.651 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.655 | Train Acc: 73.98% | Val. Loss: 0.645 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.649 | Train Acc: 76.88% | Val. Loss: 0.640 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.752 | Train Acc: 21.76% | Val. Loss: 0.745 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.744 | Train Acc: 23.98% | Val. Loss: 0.733 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.732 | Train Acc: 29.40% | Val. Loss: 0.717 | Val. Acc: 10.57% |
# | Epoch: 04 | Train Loss: 0.719 | Train Acc: 35.88% | Val. Loss: 0.702 | Val. Acc: 10.57% |
# | Epoch: 05 | Train Loss: 0.704 | Train Acc: 44.09% | Val. Loss: 0.686 | Val. Acc: 89.20% |
# | Epoch: 06 | Train Loss: 0.690 | Train Acc: 54.06% | Val. Loss: 0.672 | Val. Acc: 89.32% |
# | Epoch: 07 | Train Loss: 0.675 | Train Acc: 61.93% | Val. Loss: 0.660 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.665 | Train Acc: 67.47% | Val. Loss: 0.648 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.653 | Train Acc: 72.33% | Val. Loss: 0.638 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.643 | Train Acc: 76.34% | Val. Loss: 0.628 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.635 | Train Acc: 77.30% | Val. Loss: 0.613 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.621 | Train Acc: 81.16% | Val. Loss: 0.588 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.598 | Train Acc: 84.97% | Val. Loss: 0.556 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.565 | Train Acc: 87.41% | Val. Loss: 0.521 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.532 | Train Acc: 87.73% | Val. Loss: 0.486 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.501 | Train Acc: 87.76% | Val. Loss: 0.453 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.470 | Train Acc: 87.76% | Val. Loss: 0.425 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.444 | Train Acc: 87.76% | Val. Loss: 0.402 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.422 | Train Acc: 87.76% | Val. Loss: 0.383 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.408 | Train Acc: 87.76% | Val. Loss: 0.369 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.780 | Train Acc: 15.34% | Val. Loss: 0.758 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.759 | Train Acc: 19.74% | Val. Loss: 0.719 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.719 | Train Acc: 34.63% | Val. Loss: 0.670 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.673 | Train Acc: 63.18% | Val. Loss: 0.618 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.624 | Train Acc: 84.35% | Val. Loss: 0.569 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.576 | Train Acc: 87.44% | Val. Loss: 0.526 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.537 | Train Acc: 87.76% | Val. Loss: 0.490 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.503 | Train Acc: 87.76% | Val. Loss: 0.460 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.476 | Train Acc: 87.76% | Val. Loss: 0.435 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.453 | Train Acc: 87.76% | Val. Loss: 0.416 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.694 | Train Acc: 51.96% | Val. Loss: 0.688 | Val. Acc: 89.32% |
# | Epoch: 02 | Train Loss: 0.690 | Train Acc: 52.50% | Val. Loss: 0.683 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.684 | Train Acc: 57.36% | Val. Loss: 0.676 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.678 | Train Acc: 60.62% | Val. Loss: 0.669 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.672 | Train Acc: 66.19% | Val. Loss: 0.661 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.663 | Train Acc: 70.88% | Val. Loss: 0.652 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.656 | Train Acc: 74.52% | Val. Loss: 0.644 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.648 | Train Acc: 76.93% | Val. Loss: 0.636 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.641 | Train Acc: 79.94% | Val. Loss: 0.627 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.633 | Train Acc: 82.07% | Val. Loss: 0.620 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.717 | Train Acc: 42.59% | Val. Loss: 0.709 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.713 | Train Acc: 43.98% | Val. Loss: 0.702 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.706 | Train Acc: 47.07% | Val. Loss: 0.692 | Val. Acc: 84.66% |
# | Epoch: 04 | Train Loss: 0.700 | Train Acc: 49.91% | Val. Loss: 0.681 | Val. Acc: 89.32% |
# | Epoch: 05 | Train Loss: 0.687 | Train Acc: 53.92% | Val. Loss: 0.669 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.676 | Train Acc: 58.47% | Val. Loss: 0.657 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.661 | Train Acc: 63.52% | Val. Loss: 0.644 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.654 | Train Acc: 66.25% | Val. Loss: 0.631 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.639 | Train Acc: 69.97% | Val. Loss: 0.618 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.626 | Train Acc: 73.41% | Val. Loss: 0.605 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.761 | Train Acc: 19.01% | Val. Loss: 0.747 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.747 | Train Acc: 23.30% | Val. Loss: 0.729 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.728 | Train Acc: 30.57% | Val. Loss: 0.709 | Val. Acc: 10.57% |
# | Epoch: 04 | Train Loss: 0.711 | Train Acc: 40.57% | Val. Loss: 0.689 | Val. Acc: 89.32% |
# | Epoch: 05 | Train Loss: 0.691 | Train Acc: 52.70% | Val. Loss: 0.670 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.672 | Train Acc: 64.23% | Val. Loss: 0.652 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.657 | Train Acc: 72.10% | Val. Loss: 0.634 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.638 | Train Acc: 78.84% | Val. Loss: 0.618 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.624 | Train Acc: 82.87% | Val. Loss: 0.602 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.610 | Train Acc: 85.54% | Val. Loss: 0.588 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.781 | Train Acc: 12.50% | Val. Loss: 0.781 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.777 | Train Acc: 12.76% | Val. Loss: 0.775 | Val. Acc: 10.57% |
# | Epoch: 03 | Train Loss: 0.773 | Train Acc: 12.44% | Val. Loss: 0.768 | Val. Acc: 10.57% |
# | Epoch: 04 | Train Loss: 0.766 | Train Acc: 12.98% | Val. Loss: 0.760 | Val. Acc: 10.57% |
# | Epoch: 05 | Train Loss: 0.758 | Train Acc: 13.78% | Val. Loss: 0.751 | Val. Acc: 10.57% |
# | Epoch: 06 | Train Loss: 0.749 | Train Acc: 15.06% | Val. Loss: 0.742 | Val. Acc: 10.57% |
# | Epoch: 07 | Train Loss: 0.740 | Train Acc: 16.68% | Val. Loss: 0.732 | Val. Acc: 10.57% |
# | Epoch: 08 | Train Loss: 0.730 | Train Acc: 19.57% | Val. Loss: 0.722 | Val. Acc: 10.57% |
# | Epoch: 09 | Train Loss: 0.722 | Train Acc: 24.60% | Val. Loss: 0.712 | Val. Acc: 10.57% |
# | Epoch: 10 | Train Loss: 0.711 | Train Acc: 31.51% | Val. Loss: 0.701 | Val. Acc: 10.57% |
# | Epoch: 01 | Train Loss: 0.667 | Train Acc: 67.67% | Val. Loss: 0.655 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.659 | Train Acc: 72.05% | Val. Loss: 0.639 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.643 | Train Acc: 78.64% | Val. Loss: 0.619 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.624 | Train Acc: 83.66% | Val. Loss: 0.597 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.605 | Train Acc: 86.42% | Val. Loss: 0.575 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.582 | Train Acc: 87.56% | Val. Loss: 0.554 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.563 | Train Acc: 87.70% | Val. Loss: 0.535 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.545 | Train Acc: 87.73% | Val. Loss: 0.519 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.531 | Train Acc: 87.76% | Val. Loss: 0.504 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.516 | Train Acc: 87.76% | Val. Loss: 0.491 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.688 | Train Acc: 53.89% | Val. Loss: 0.680 | Val. Acc: 89.32% |
# | Epoch: 02 | Train Loss: 0.685 | Train Acc: 56.11% | Val. Loss: 0.670 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.672 | Train Acc: 62.93% | Val. Loss: 0.657 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.661 | Train Acc: 68.04% | Val. Loss: 0.642 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.645 | Train Acc: 75.37% | Val. Loss: 0.627 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.633 | Train Acc: 79.49% | Val. Loss: 0.612 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.617 | Train Acc: 83.07% | Val. Loss: 0.597 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.604 | Train Acc: 85.31% | Val. Loss: 0.583 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.591 | Train Acc: 86.90% | Val. Loss: 0.569 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.576 | Train Acc: 87.30% | Val. Loss: 0.556 | Val. Acc: 89.43% |
# | Epoch: 01 | Train Loss: 0.659 | Train Acc: 77.87% | Val. Loss: 0.644 | Val. Acc: 89.43% |
# | Epoch: 02 | Train Loss: 0.647 | Train Acc: 81.93% | Val. Loss: 0.621 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.627 | Train Acc: 86.42% | Val. Loss: 0.593 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.598 | Train Acc: 87.64% | Val. Loss: 0.560 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.568 | Train Acc: 87.76% | Val. Loss: 0.527 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.536 | Train Acc: 87.76% | Val. Loss: 0.495 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.508 | Train Acc: 87.76% | Val. Loss: 0.467 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.480 | Train Acc: 87.76% | Val. Loss: 0.442 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.458 | Train Acc: 87.76% | Val. Loss: 0.421 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.439 | Train Acc: 87.76% | Val. Loss: 0.404 | Val. Acc: 89.43% |

# %%
print("The hyperparameters used for the model in task B are")
print(f'embedding_dim: {int(taskB_opt.X[-1][0])}')
print(f'hidden_dim: {int(taskB_opt.X[-1][2])}')
print(f'drop_out: {taskB_opt.X[-1][3]:.2f}')
print(f'learning_rate: {taskB_opt.X[-1][4]:.4f}')
print(f'weight_decay: {taskB_opt.X[-1][5]:.4f}')
# Out:
# The hyperparameters used for the model in task B are
# embedding_dim: 100
# hidden_dim: 64
# drop_out: 0.34
# learning_rate: 0.0100
# weight_decay: 0.8571

# %%
# CNN(vocab_size, embedding_dim, out_channels, window_size, output_dim, dropout)
# test_model_B = CNN(INPUT_DIM, int(taskB_opt.X[-1][0]), int(taskB_opt.X[-1][1]), WINDOW_SIZE, OUTPUT_DIM, taskB_opt.X[-1][3])
# LSTMClassifier(vocab_size, embedding_dim, hidden_dim, label_size, output_dim, dropout)
test_model_B = LSTMClassifier(INPUT_DIM, int(taskB_opt.X[-1][0]), int(taskB_opt.X[-1][2]), 2, OUTPUT_DIM, taskB_opt.X[-1][3])
optimizer_B = optim.SGD(test_model_B.parameters(), lr=taskB_opt.X[-1][4], momentum=taskB_opt.X[-1][5])
train_part(test_model_B, tweets_b_tensor, labels_b_tensor, optimizer_B, epochs=50)
# Out:
# | Epoch: 01 | Train Loss: 0.725 | Train Acc: 25.23% | Val. Loss: 0.703 | Val. Acc: 10.57% |
# | Epoch: 02 | Train Loss: 0.705 | Train Acc: 39.43% | Val. Loss: 0.666 | Val. Acc: 89.43% |
# | Epoch: 03 | Train Loss: 0.667 | Train Acc: 74.20% | Val. Loss: 0.620 | Val. Acc: 89.43% |
# | Epoch: 04 | Train Loss: 0.623 | Train Acc: 87.33% | Val. Loss: 0.571 | Val. Acc: 89.43% |
# | Epoch: 05 | Train Loss: 0.578 | Train Acc: 87.76% | Val. Loss: 0.525 | Val. Acc: 89.43% |
# | Epoch: 06 | Train Loss: 0.533 | Train Acc: 87.76% | Val. Loss: 0.484 | Val. Acc: 89.43% |
# | Epoch: 07 | Train Loss: 0.496 | Train Acc: 87.76% | Val. Loss: 0.450 | Val. Acc: 89.43% |
# | Epoch: 08 | Train Loss: 0.465 | Train Acc: 87.76% | Val. Loss: 0.424 | Val. Acc: 89.43% |
# | Epoch: 09 | Train Loss: 0.441 | Train Acc: 87.76% | Val. Loss: 0.403 | Val. Acc: 89.43% |
# | Epoch: 10 | Train Loss: 0.423 | Train Acc: 87.76% | Val. Loss: 0.387 | Val. Acc: 89.43% |
# | Epoch: 11 | Train Loss: 0.409 | Train Acc: 87.76% | Val. Loss: 0.375 | Val. Acc: 89.43% |
# | Epoch: 12 | Train Loss: 0.398 | Train Acc: 87.76% | Val. Loss: 0.365 | Val. Acc: 89.43% |
# | Epoch: 13 | Train Loss: 0.391 | Train Acc: 87.76% | Val. Loss: 0.357 | Val. Acc: 89.43% |
# | Epoch: 14 | Train Loss: 0.385 | Train Acc: 87.76% | Val. Loss: 0.352 | Val. Acc: 89.43% |
# | Epoch: 15 | Train Loss: 0.381 | Train Acc: 87.76% | Val. Loss: 0.347 | Val. Acc: 89.43% |
# | Epoch: 16 | Train Loss: 0.377 | Train Acc: 87.76% | Val. Loss: 0.344 | Val. Acc: 89.43% |
# | Epoch: 17 | Train Loss: 0.377 | Train Acc: 87.76% | Val. Loss: 0.342 | Val. Acc: 89.43% |
# | Epoch: 18 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.341 | Val. Acc: 89.43% |
# | Epoch: 19 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.339 | Val. Acc: 89.43% |
# | Epoch: 20 | Train Loss: 0.376 | Train Acc: 87.76% | Val. Loss: 0.339 | Val. Acc: 89.43% |
# | Epoch: 21 | Train Loss: 0.373 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 22 | Train Loss: 0.372 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 23 | Train Loss: 0.377 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 24 | Train Loss: 0.377 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 25 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 26 | Train Loss: 0.374 | Train Acc: 87.76% | Val. Loss: 0.337 | Val. Acc: 89.43% |
# | Epoch: 27 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.337 | Val. Acc: 89.43% |
# | Epoch: 28 | Train Loss: 0.377 | Train Acc: 87.76% | Val. Loss: 0.337 | Val. Acc: 89.43% |
# | Epoch: 29 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.337 | Val. Acc: 89.43% |
# | Epoch: 30 | Train Loss: 0.376 | Train Acc: 87.76% | Val. Loss: 0.337 | Val. Acc: 89.43% |
# | Epoch: 31 | Train Loss: 0.378 | Train Acc: 87.76% | Val. Loss: 0.337 | Val. Acc: 89.43% |
# | Epoch: 32 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.337 | Val. Acc: 89.43% |
# | Epoch: 33 | Train Loss: 0.377 | Train Acc: 87.76% | Val. Loss: 0.337 | Val. Acc: 89.43% |
# | Epoch: 34 | Train Loss: 0.378 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 35 | Train Loss: 0.373 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 36 | Train Loss: 0.378 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 37 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 38 | Train Loss: 0.376 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 39 | Train Loss: 0.377 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 40 | Train Loss: 0.374 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 41 | Train Loss: 0.376 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 42 | Train Loss: 0.374 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 43 | Train Loss: 0.376 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 44 | Train Loss: 0.374 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 45 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 46 | Train Loss: 0.374 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 47 | Train Loss: 0.373 | Train Acc: 87.76% | Val. Loss: 0.338 | Val. Acc: 89.43% |
# | Epoch: 48 | Train Loss: 0.375 | Train Acc: 87.76% | Val. Loss: 0.339 | Val. Acc: 89.43% |
# | Epoch: 49 | Train Loss: 0.374 | Train Acc: 87.76% | Val. Loss: 0.339 | Val. Acc: 89.43% |
# | Epoch: 50 | Train Loss: 0.374 | Train Acc: 87.76% | Val. Loss: 0.339 | Val. Acc: 89.43% |
# tensor(0.8943)

# %%
_, feature_valid, _, target_valid = train_valid_split(tweets_b_tensor, labels_b_tensor, 0.2)

test_model_B.eval()

with torch.no_grad():
  predictions = test_model_B(feature_valid).squeeze(1)
  acc = check_accuracy(predictions, target_valid)
  score = check_f1_score(predictions, target_valid)

print(f'Validation Accuracy: {acc:.4f}')
print(f'Validation F1 Score: {score:.4f}')
# Out:
# Validation Accuracy: 0.8943
# Validation F1 Score: 0.4721

# %%
INPUT_DIM = len(word2index)
OUTPUT_DIM = 3

# window size
WINDOW_SIZE = 1

def taskC_tuning(params):
  param = params[0]
  # CNN(vocab_size, embedding_dim, out_channels, window_size, output_dim, dropout)
  # model = CNN(INPUT_DIM, int(param[0]), int(param[1]), WINDOW_SIZE, OUTPUT_DIM, param[3])
  # LSTMClassifier(vocab_size, embedding_dim, hidden_dim, label_size, output_dim, dropout)
  model = LSTMClassifier(INPUT_DIM, int(param[0]), int(param[2]), 2, OUTPUT_DIM, param[3])
  optimizer = optim.SGD(model.parameters(), lr=param[4], momentum=param[5])
  acc = train_part(model, tweets_c_tensor, labels_c_tensor, optimizer, epochs=10, num_class=3)
  return acc

taskC_opt = BayesianOptimization(f=taskC_tuning,
                                 domain=domain,
                                 model_type='GP',
                                 acquisition_type='EI',
                                 acquisition_jitter=0.05,
                                 maximize=True)

taskC_opt.run_optimization(max_iter=20)
# Out:
# | Epoch: 01 | Train Loss: 1.050 | Train Acc: 51.63% | Val. Loss: 1.044 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.042 | Train Acc: 53.11% | Val. Loss: 1.038 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.039 | Train Acc: 54.18% | Val. Loss: 1.032 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.032 | Train Acc: 55.14% | Val. Loss: 1.025 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.024 | Train Acc: 56.43% | Val. Loss: 1.019 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.023 | Train Acc: 56.37% | Val. Loss: 1.013 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.010 | Train Acc: 59.24% | Val. Loss: 1.007 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.005 | Train Acc: 59.88% | Val. Loss: 1.001 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.998 | Train Acc: 59.40% | Val. Loss: 0.996 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.995 | Train Acc: 60.01% | Val. Loss: 0.992 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.121 | Train Acc: 24.73% | Val. Loss: 1.113 | Val. Acc: 10.19% |
# | Epoch: 02 | Train Loss: 1.116 | Train Acc: 26.80% | Val. Loss: 1.104 | Val. Acc: 10.19% |
# | Epoch: 03 | Train Loss: 1.106 | Train Acc: 30.22% | Val. Loss: 1.090 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.088 | Train Acc: 39.12% | Val. Loss: 1.074 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.069 | Train Acc: 48.47% | Val. Loss: 1.057 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.052 | Train Acc: 55.40% | Val. Loss: 1.038 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.033 | Train Acc: 59.69% | Val. Loss: 1.020 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.015 | Train Acc: 61.63% | Val. Loss: 1.003 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.994 | Train Acc: 62.43% | Val. Loss: 0.987 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.977 | Train Acc: 62.59% | Val. Loss: 0.973 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.144 | Train Acc: 19.99% | Val. Loss: 1.126 | Val. Acc: 10.19% |
# | Epoch: 02 | Train Loss: 1.128 | Train Acc: 22.41% | Val. Loss: 1.106 | Val. Acc: 10.19% |
# | Epoch: 03 | Train Loss: 1.112 | Train Acc: 29.93% | Val. Loss: 1.083 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.085 | Train Acc: 42.21% | Val. Loss: 1.060 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.061 | Train Acc: 51.18% | Val. Loss: 1.039 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.039 | Train Acc: 58.27% | Val. Loss: 1.020 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.017 | Train Acc: 60.95% | Val. Loss: 1.003 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.994 | Train Acc: 61.98% | Val. Loss: 0.988 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.979 | Train Acc: 62.17% | Val. Loss: 0.976 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.967 | Train Acc: 62.62% | Val. Loss: 0.965 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.086 | Train Acc: 32.57% | Val. Loss: 1.067 | Val. Acc: 29.81% |
# | Epoch: 02 | Train Loss: 1.079 | Train Acc: 33.02% | Val. Loss: 1.054 | Val. Acc: 29.81% |
# | Epoch: 03 | Train Loss: 1.064 | Train Acc: 35.25% | Val. Loss: 1.038 | Val. Acc: 29.81% |
# | Epoch: 04 | Train Loss: 1.050 | Train Acc: 37.70% | Val. Loss: 1.023 | Val. Acc: 29.81% |
# | Epoch: 05 | Train Loss: 1.030 | Train Acc: 44.11% | Val. Loss: 1.009 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.017 | Train Acc: 47.66% | Val. Loss: 0.996 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.999 | Train Acc: 51.44% | Val. Loss: 0.984 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.986 | Train Acc: 54.14% | Val. Loss: 0.974 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.977 | Train Acc: 56.98% | Val. Loss: 0.965 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.967 | Train Acc: 58.98% | Val. Loss: 0.957 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.030 | Train Acc: 57.08% | Val. Loss: 1.026 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.022 | Train Acc: 58.98% | Val. Loss: 1.017 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.016 | Train Acc: 59.92% | Val. Loss: 1.006 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.001 | Train Acc: 60.85% | Val. Loss: 0.996 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.991 | Train Acc: 61.92% | Val. Loss: 0.986 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.980 | Train Acc: 62.04% | Val. Loss: 0.976 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.973 | Train Acc: 62.30% | Val. Loss: 0.968 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.960 | Train Acc: 62.33% | Val. Loss: 0.961 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.951 | Train Acc: 62.62% | Val. Loss: 0.955 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.945 | Train Acc: 62.50% | Val. Loss: 0.950 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.065 | Train Acc: 45.28% | Val. Loss: 1.051 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.052 | Train Acc: 50.24% | Val. Loss: 1.031 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.034 | Train Acc: 53.43% | Val. Loss: 1.009 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.006 | Train Acc: 59.66% | Val. Loss: 0.985 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.981 | Train Acc: 61.69% | Val. Loss: 0.964 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.958 | Train Acc: 62.40% | Val. Loss: 0.946 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.938 | Train Acc: 62.56% | Val. Loss: 0.933 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.923 | Train Acc: 62.62% | Val. Loss: 0.923 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.913 | Train Acc: 62.62% | Val. Loss: 0.917 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.904 | Train Acc: 62.62% | Val. Loss: 0.913 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.033 | Train Acc: 62.17% | Val. Loss: 1.026 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.020 | Train Acc: 62.40% | Val. Loss: 1.009 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.002 | Train Acc: 62.62% | Val. Loss: 0.989 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 0.981 | Train Acc: 62.62% | Val. Loss: 0.970 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.958 | Train Acc: 62.62% | Val. Loss: 0.954 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.939 | Train Acc: 62.62% | Val. Loss: 0.941 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.924 | Train Acc: 62.62% | Val. Loss: 0.931 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.914 | Train Acc: 62.62% | Val. Loss: 0.924 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.906 | Train Acc: 62.62% | Val. Loss: 0.920 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.897 | Train Acc: 62.62% | Val. Loss: 0.917 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.144 | Train Acc: 28.09% | Val. Loss: 1.135 | Val. Acc: 10.19% |
# | Epoch: 02 | Train Loss: 1.148 | Train Acc: 27.06% | Val. Loss: 1.132 | Val. Acc: 10.19% |
# | Epoch: 03 | Train Loss: 1.147 | Train Acc: 25.67% | Val. Loss: 1.128 | Val. Acc: 10.19% |
# | Epoch: 04 | Train Loss: 1.131 | Train Acc: 30.22% | Val. Loss: 1.124 | Val. Acc: 10.19% |
# | Epoch: 05 | Train Loss: 1.132 | Train Acc: 29.99% | Val. Loss: 1.119 | Val. Acc: 10.19% |
# | Epoch: 06 | Train Loss: 1.130 | Train Acc: 30.67% | Val. Loss: 1.115 | Val. Acc: 10.19% |
# | Epoch: 07 | Train Loss: 1.127 | Train Acc: 30.54% | Val. Loss: 1.111 | Val. Acc: 10.19% |
# | Epoch: 08 | Train Loss: 1.121 | Train Acc: 31.31% | Val. Loss: 1.106 | Val. Acc: 10.19% |
# | Epoch: 09 | Train Loss: 1.117 | Train Acc: 32.09% | Val. Loss: 1.102 | Val. Acc: 10.32% |
# | Epoch: 10 | Train Loss: 1.113 | Train Acc: 32.12% | Val. Loss: 1.098 | Val. Acc: 10.32% |
# | Epoch: 01 | Train Loss: 0.965 | Train Acc: 61.14% | Val. Loss: 0.955 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 0.958 | Train Acc: 61.34% | Val. Loss: 0.945 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 0.949 | Train Acc: 61.21% | Val. Loss: 0.933 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 0.935 | Train Acc: 62.04% | Val. Loss: 0.922 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.920 | Train Acc: 62.50% | Val. Loss: 0.913 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.908 | Train Acc: 62.66% | Val. Loss: 0.908 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.906 | Train Acc: 62.62% | Val. Loss: 0.905 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.893 | Train Acc: 62.66% | Val. Loss: 0.905 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.895 | Train Acc: 62.62% | Val. Loss: 0.907 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.895 | Train Acc: 62.62% | Val. Loss: 0.909 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.038 | Train Acc: 48.47% | Val. Loss: 1.024 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.027 | Train Acc: 50.11% | Val. Loss: 1.014 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.016 | Train Acc: 52.11% | Val. Loss: 1.003 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.006 | Train Acc: 53.18% | Val. Loss: 0.992 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.994 | Train Acc: 55.53% | Val. Loss: 0.982 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.983 | Train Acc: 55.82% | Val. Loss: 0.972 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.970 | Train Acc: 58.79% | Val. Loss: 0.964 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.965 | Train Acc: 59.05% | Val. Loss: 0.957 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.955 | Train Acc: 59.34% | Val. Loss: 0.950 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.951 | Train Acc: 60.21% | Val. Loss: 0.945 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.163 | Train Acc: 20.90% | Val. Loss: 1.143 | Val. Acc: 29.81% |
# | Epoch: 02 | Train Loss: 1.151 | Train Acc: 21.19% | Val. Loss: 1.127 | Val. Acc: 29.81% |
# | Epoch: 03 | Train Loss: 1.133 | Train Acc: 23.12% | Val. Loss: 1.109 | Val. Acc: 29.94% |
# | Epoch: 04 | Train Loss: 1.113 | Train Acc: 28.73% | Val. Loss: 1.090 | Val. Acc: 30.32% |
# | Epoch: 05 | Train Loss: 1.092 | Train Acc: 38.76% | Val. Loss: 1.073 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.074 | Train Acc: 49.79% | Val. Loss: 1.056 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.055 | Train Acc: 54.40% | Val. Loss: 1.041 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.037 | Train Acc: 60.08% | Val. Loss: 1.028 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 1.024 | Train Acc: 61.37% | Val. Loss: 1.015 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 1.009 | Train Acc: 62.30% | Val. Loss: 1.004 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.131 | Train Acc: 23.06% | Val. Loss: 1.126 | Val. Acc: 10.19% |
# | Epoch: 02 | Train Loss: 1.132 | Train Acc: 23.64% | Val. Loss: 1.126 | Val. Acc: 10.19% |
# | Epoch: 03 | Train Loss: 1.128 | Train Acc: 24.38% | Val. Loss: 1.125 | Val. Acc: 10.19% |
# | Epoch: 04 | Train Loss: 1.131 | Train Acc: 23.02% | Val. Loss: 1.125 | Val. Acc: 10.19% |
# | Epoch: 05 | Train Loss: 1.129 | Train Acc: 24.41% | Val. Loss: 1.124 | Val. Acc: 10.19% |
# | Epoch: 06 | Train Loss: 1.131 | Train Acc: 23.44% | Val. Loss: 1.124 | Val. Acc: 10.19% |
# | Epoch: 07 | Train Loss: 1.128 | Train Acc: 22.77% | Val. Loss: 1.123 | Val. Acc: 10.19% |
# | Epoch: 08 | Train Loss: 1.124 | Train Acc: 24.31% | Val. Loss: 1.123 | Val. Acc: 10.19% |
# | Epoch: 09 | Train Loss: 1.123 | Train Acc: 24.80% | Val. Loss: 1.122 | Val. Acc: 10.19% |
# | Epoch: 10 | Train Loss: 1.125 | Train Acc: 25.57% | Val. Loss: 1.121 | Val. Acc: 10.19% |
# | Epoch: 01 | Train Loss: 1.073 | Train Acc: 43.44% | Val. Loss: 1.055 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.057 | Train Acc: 47.31% | Val. Loss: 1.033 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.034 | Train Acc: 53.47% | Val. Loss: 1.007 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.010 | Train Acc: 57.66% | Val. Loss: 0.981 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.976 | Train Acc: 61.14% | Val. Loss: 0.957 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.951 | Train Acc: 62.27% | Val. Loss: 0.938 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.934 | Train Acc: 62.56% | Val. Loss: 0.925 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.913 | Train Acc: 62.62% | Val. Loss: 0.918 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.905 | Train Acc: 62.59% | Val. Loss: 0.915 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.901 | Train Acc: 62.62% | Val. Loss: 0.916 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 0.965 | Train Acc: 62.37% | Val. Loss: 0.966 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 0.961 | Train Acc: 62.27% | Val. Loss: 0.953 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 0.944 | Train Acc: 62.59% | Val. Loss: 0.939 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 0.930 | Train Acc: 62.62% | Val. Loss: 0.926 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.914 | Train Acc: 62.62% | Val. Loss: 0.917 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.898 | Train Acc: 62.62% | Val. Loss: 0.912 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.896 | Train Acc: 62.62% | Val. Loss: 0.910 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.889 | Train Acc: 62.62% | Val. Loss: 0.910 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.888 | Train Acc: 62.62% | Val. Loss: 0.912 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.891 | Train Acc: 62.62% | Val. Loss: 0.913 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.156 | Train Acc: 18.48% | Val. Loss: 1.134 | Val. Acc: 10.19% |
# | Epoch: 02 | Train Loss: 1.137 | Train Acc: 22.32% | Val. Loss: 1.114 | Val. Acc: 10.19% |
# | Epoch: 03 | Train Loss: 1.117 | Train Acc: 28.09% | Val. Loss: 1.091 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.092 | Train Acc: 36.38% | Val. Loss: 1.069 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.072 | Train Acc: 44.99% | Val. Loss: 1.049 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.050 | Train Acc: 54.63% | Val. Loss: 1.030 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.032 | Train Acc: 56.92% | Val. Loss: 1.014 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.011 | Train Acc: 60.27% | Val. Loss: 1.000 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.994 | Train Acc: 61.63% | Val. Loss: 0.988 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.979 | Train Acc: 61.92% | Val. Loss: 0.978 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.095 | Train Acc: 35.54% | Val. Loss: 1.071 | Val. Acc: 29.81% |
# | Epoch: 02 | Train Loss: 1.079 | Train Acc: 39.31% | Val. Loss: 1.051 | Val. Acc: 29.94% |
# | Epoch: 03 | Train Loss: 1.057 | Train Acc: 44.95% | Val. Loss: 1.031 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.040 | Train Acc: 47.47% | Val. Loss: 1.012 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.018 | Train Acc: 52.08% | Val. Loss: 0.995 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.994 | Train Acc: 57.05% | Val. Loss: 0.980 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.978 | Train Acc: 58.79% | Val. Loss: 0.968 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.969 | Train Acc: 60.59% | Val. Loss: 0.958 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.953 | Train Acc: 61.75% | Val. Loss: 0.950 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.946 | Train Acc: 62.33% | Val. Loss: 0.943 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.066 | Train Acc: 49.05% | Val. Loss: 1.060 | Val. Acc: 59.87% |
# | Epoch: 02 | Train Loss: 1.058 | Train Acc: 52.60% | Val. Loss: 1.054 | Val. Acc: 59.87% |
# | Epoch: 03 | Train Loss: 1.055 | Train Acc: 53.18% | Val. Loss: 1.047 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.049 | Train Acc: 53.69% | Val. Loss: 1.039 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.035 | Train Acc: 57.01% | Val. Loss: 1.030 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.027 | Train Acc: 57.66% | Val. Loss: 1.022 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.022 | Train Acc: 58.30% | Val. Loss: 1.013 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.010 | Train Acc: 59.56% | Val. Loss: 1.004 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 1.001 | Train Acc: 60.21% | Val. Loss: 0.996 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.993 | Train Acc: 60.98% | Val. Loss: 0.989 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.149 | Train Acc: 21.03% | Val. Loss: 1.138 | Val. Acc: 10.19% |
# | Epoch: 02 | Train Loss: 1.141 | Train Acc: 22.41% | Val. Loss: 1.137 | Val. Acc: 10.19% |
# | Epoch: 03 | Train Loss: 1.151 | Train Acc: 21.28% | Val. Loss: 1.137 | Val. Acc: 10.19% |
# | Epoch: 04 | Train Loss: 1.145 | Train Acc: 23.25% | Val. Loss: 1.136 | Val. Acc: 10.19% |
# | Epoch: 05 | Train Loss: 1.148 | Train Acc: 20.96% | Val. Loss: 1.135 | Val. Acc: 10.19% |
# | Epoch: 06 | Train Loss: 1.142 | Train Acc: 23.90% | Val. Loss: 1.135 | Val. Acc: 10.19% |
# | Epoch: 07 | Train Loss: 1.145 | Train Acc: 23.02% | Val. Loss: 1.134 | Val. Acc: 10.19% |
# | Epoch: 08 | Train Loss: 1.143 | Train Acc: 22.99% | Val. Loss: 1.133 | Val. Acc: 10.19% |
# | Epoch: 09 | Train Loss: 1.142 | Train Acc: 23.96% | Val. Loss: 1.133 | Val. Acc: 10.19% |
# | Epoch: 10 | Train Loss: 1.138 | Train Acc: 23.67% | Val. Loss: 1.132 | Val. Acc: 10.19% |
# | Epoch: 01 | Train Loss: 1.078 | Train Acc: 40.44% | Val. Loss: 1.047 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.051 | Train Acc: 48.21% | Val. Loss: 1.015 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.020 | Train Acc: 56.43% | Val. Loss: 0.980 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 0.978 | Train Acc: 61.50% | Val. Loss: 0.950 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.944 | Train Acc: 62.62% | Val. Loss: 0.928 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.921 | Train Acc: 62.59% | Val. Loss: 0.915 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.905 | Train Acc: 62.66% | Val. Loss: 0.911 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.896 | Train Acc: 62.59% | Val. Loss: 0.912 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.894 | Train Acc: 62.62% | Val. Loss: 0.915 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.899 | Train Acc: 62.62% | Val. Loss: 0.918 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.043 | Train Acc: 54.47% | Val. Loss: 1.039 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.035 | Train Acc: 56.37% | Val. Loss: 1.030 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.024 | Train Acc: 59.05% | Val. Loss: 1.019 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.015 | Train Acc: 59.88% | Val. Loss: 1.007 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.001 | Train Acc: 61.30% | Val. Loss: 0.995 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.987 | Train Acc: 61.92% | Val. Loss: 0.985 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.976 | Train Acc: 62.33% | Val. Loss: 0.975 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.969 | Train Acc: 62.37% | Val. Loss: 0.966 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.958 | Train Acc: 62.50% | Val. Loss: 0.959 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.950 | Train Acc: 62.62% | Val. Loss: 0.952 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.207 | Train Acc: 17.74% | Val. Loss: 1.163 | Val. Acc: 10.19% |
# | Epoch: 02 | Train Loss: 1.181 | Train Acc: 21.54% | Val. Loss: 1.118 | Val. Acc: 10.32% |
# | Epoch: 03 | Train Loss: 1.126 | Train Acc: 29.96% | Val. Loss: 1.076 | Val. Acc: 59.87% |
# | Epoch: 04 | Train Loss: 1.084 | Train Acc: 42.63% | Val. Loss: 1.040 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.049 | Train Acc: 49.18% | Val. Loss: 1.012 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.017 | Train Acc: 55.30% | Val. Loss: 0.990 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.991 | Train Acc: 59.17% | Val. Loss: 0.973 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.976 | Train Acc: 59.21% | Val. Loss: 0.960 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.962 | Train Acc: 60.69% | Val. Loss: 0.950 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.956 | Train Acc: 60.08% | Val. Loss: 0.942 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.043 | Train Acc: 58.21% | Val. Loss: 1.046 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.045 | Train Acc: 57.37% | Val. Loss: 1.046 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.044 | Train Acc: 57.79% | Val. Loss: 1.045 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.044 | Train Acc: 57.85% | Val. Loss: 1.045 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.044 | Train Acc: 57.56% | Val. Loss: 1.044 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.039 | Train Acc: 59.37% | Val. Loss: 1.043 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.039 | Train Acc: 58.92% | Val. Loss: 1.042 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.038 | Train Acc: 58.95% | Val. Loss: 1.041 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 1.037 | Train Acc: 58.79% | Val. Loss: 1.040 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 1.035 | Train Acc: 59.24% | Val. Loss: 1.039 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.026 | Train Acc: 60.85% | Val. Loss: 1.031 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.027 | Train Acc: 60.98% | Val. Loss: 1.031 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.027 | Train Acc: 60.24% | Val. Loss: 1.030 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.025 | Train Acc: 60.85% | Val. Loss: 1.030 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.024 | Train Acc: 61.04% | Val. Loss: 1.029 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.025 | Train Acc: 61.08% | Val. Loss: 1.028 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.023 | Train Acc: 60.59% | Val. Loss: 1.027 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.022 | Train Acc: 61.40% | Val. Loss: 1.026 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 1.021 | Train Acc: 61.53% | Val. Loss: 1.025 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 1.020 | Train Acc: 61.69% | Val. Loss: 1.023 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.044 | Train Acc: 42.21% | Val. Loss: 1.019 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.030 | Train Acc: 45.44% | Val. Loss: 0.993 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 0.998 | Train Acc: 52.50% | Val. Loss: 0.966 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 0.967 | Train Acc: 57.79% | Val. Loss: 0.942 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 0.939 | Train Acc: 60.63% | Val. Loss: 0.924 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 0.921 | Train Acc: 62.11% | Val. Loss: 0.914 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 0.908 | Train Acc: 62.43% | Val. Loss: 0.910 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 0.903 | Train Acc: 62.59% | Val. Loss: 0.910 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 0.903 | Train Acc: 62.62% | Val. Loss: 0.913 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 0.896 | Train Acc: 62.62% | Val. Loss: 0.918 | Val. Acc: 60.00% |
# | Epoch: 01 | Train Loss: 1.071 | Train Acc: 45.66% | Val. Loss: 1.070 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.072 | Train Acc: 44.95% | Val. Loss: 1.070 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.070 | Train Acc: 48.40% | Val. Loss: 1.069 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.070 | Train Acc: 48.05% | Val. Loss: 1.069 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.069 | Train Acc: 47.66% | Val. Loss: 1.068 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.068 | Train Acc: 48.79% | Val. Loss: 1.067 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.067 | Train Acc: 48.18% | Val. Loss: 1.066 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.068 | Train Acc: 48.27% | Val. Loss: 1.065 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 1.066 | Train Acc: 49.11% | Val. Loss: 1.064 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 1.065 | Train Acc: 50.34% | Val. Loss: 1.063 | Val. Acc: 60.00% |

# %%
print("The hyperparameters used for the model in task C are")
print(f'embedding_dim: {int(taskC_opt.X[-1][0])}')
print(f'hidden_dim: {int(taskC_opt.X[-1][2])}')
print(f'drop_out: {taskC_opt.X[-1][3]:.2f}')
print(f'learning_rate: {taskC_opt.X[-1][4]:.4f}')
print(f'weight_decay: {taskC_opt.X[-1][5]:.4f}')
# Out:
# The hyperparameters used for the model in task C are
# embedding_dim: 100
# hidden_dim: 128
# drop_out: 0.20
# learning_rate: 0.0001
# weight_decay: 0.9000

# %%
# CNN(vocab_size, embedding_dim, out_channels, window_size, output_dim, dropout)
# test_model_C = CNN(INPUT_DIM, int(taskC_opt.X[-1][0]), int(taskC_opt.X[-1][1]), WINDOW_SIZE, OUTPUT_DIM, taskC_opt.X[-1][3])
# LSTMClassifier(vocab_size, embedding_dim, hidden_dim, label_size, output_dim, dropout)
test_model_C = LSTMClassifier(INPUT_DIM, int(taskC_opt.X[-1][0]), int(taskC_opt.X[-1][2]), 2, OUTPUT_DIM, taskC_opt.X[-1][3])
optimizer_C = optim.SGD(test_model_C.parameters(), lr=taskC_opt.X[-1][4], momentum=taskC_opt.X[-1][5])
train_part(test_model_C, tweets_c_tensor, labels_c_tensor, optimizer_C, epochs=50, num_class=3)
# Out:
# | Epoch: 01 | Train Loss: 1.042 | Train Acc: 62.14% | Val. Loss: 1.048 | Val. Acc: 60.00% |
# | Epoch: 02 | Train Loss: 1.042 | Train Acc: 62.27% | Val. Loss: 1.048 | Val. Acc: 60.00% |
# | Epoch: 03 | Train Loss: 1.041 | Train Acc: 62.11% | Val. Loss: 1.048 | Val. Acc: 60.00% |
# | Epoch: 04 | Train Loss: 1.041 | Train Acc: 62.40% | Val. Loss: 1.048 | Val. Acc: 60.00% |
# | Epoch: 05 | Train Loss: 1.040 | Train Acc: 62.14% | Val. Loss: 1.047 | Val. Acc: 60.00% |
# | Epoch: 06 | Train Loss: 1.041 | Train Acc: 62.04% | Val. Loss: 1.047 | Val. Acc: 60.00% |
# | Epoch: 07 | Train Loss: 1.040 | Train Acc: 62.21% | Val. Loss: 1.046 | Val. Acc: 60.00% |
# | Epoch: 08 | Train Loss: 1.040 | Train Acc: 62.14% | Val. Loss: 1.045 | Val. Acc: 60.00% |
# | Epoch: 09 | Train Loss: 1.038 | Train Acc: 62.21% | Val. Loss: 1.045 | Val. Acc: 60.00% |
# | Epoch: 10 | Train Loss: 1.039 | Train Acc: 62.33% | Val. Loss: 1.044 | Val. Acc: 60.00% |
# | Epoch: 11 | Train Loss: 1.035 | Train Acc: 62.24% | Val. Loss: 1.043 | Val. Acc: 60.00% |
# | Epoch: 12 | Train Loss: 1.035 | Train Acc: 62.27% | Val. Loss: 1.042 | Val. Acc: 60.00% |
# | Epoch: 13 | Train Loss: 1.033 | Train Acc: 62.43% | Val. Loss: 1.042 | Val. Acc: 60.00% |
# | Epoch: 14 | Train Loss: 1.034 | Train Acc: 62.37% | Val. Loss: 1.041 | Val. Acc: 60.00% |
# | Epoch: 15 | Train Loss: 1.033 | Train Acc: 62.30% | Val. Loss: 1.040 | Val. Acc: 60.00% |
# | Epoch: 16 | Train Loss: 1.033 | Train Acc: 62.53% | Val. Loss: 1.039 | Val. Acc: 60.00% |
# | Epoch: 17 | Train Loss: 1.032 | Train Acc: 62.53% | Val. Loss: 1.038 | Val. Acc: 60.00% |
# | Epoch: 18 | Train Loss: 1.029 | Train Acc: 62.53% | Val. Loss: 1.037 | Val. Acc: 60.00% |
# | Epoch: 19 | Train Loss: 1.029 | Train Acc: 62.56% | Val. Loss: 1.036 | Val. Acc: 60.00% |
# | Epoch: 20 | Train Loss: 1.028 | Train Acc: 62.53% | Val. Loss: 1.036 | Val. Acc: 60.00% |
# | Epoch: 21 | Train Loss: 1.027 | Train Acc: 62.53% | Val. Loss: 1.035 | Val. Acc: 60.00% |
# | Epoch: 22 | Train Loss: 1.028 | Train Acc: 62.37% | Val. Loss: 1.034 | Val. Acc: 60.00% |
# | Epoch: 23 | Train Loss: 1.025 | Train Acc: 62.56% | Val. Loss: 1.033 | Val. Acc: 60.00% |
# | Epoch: 24 | Train Loss: 1.026 | Train Acc: 62.62% | Val. Loss: 1.032 | Val. Acc: 60.00% |
# | Epoch: 25 | Train Loss: 1.025 | Train Acc: 62.59% | Val. Loss: 1.031 | Val. Acc: 60.00% |
# | Epoch: 26 | Train Loss: 1.022 | Train Acc: 62.59% | Val. Loss: 1.030 | Val. Acc: 60.00% |
# | Epoch: 27 | Train Loss: 1.022 | Train Acc: 62.59% | Val. Loss: 1.029 | Val. Acc: 60.00% |
# | Epoch: 28 | Train Loss: 1.020 | Train Acc: 62.50% | Val. Loss: 1.028 | Val. Acc: 60.00% |
# | Epoch: 29 | Train Loss: 1.018 | Train Acc: 62.59% | Val. Loss: 1.027 | Val. Acc: 60.00% |
# | Epoch: 30 | Train Loss: 1.019 | Train Acc: 62.62% | Val. Loss: 1.026 | Val. Acc: 60.00% |
# | Epoch: 31 | Train Loss: 1.018 | Train Acc: 62.62% | Val. Loss: 1.025 | Val. Acc: 60.00% |
# | Epoch: 32 | Train Loss: 1.018 | Train Acc: 62.59% | Val. Loss: 1.024 | Val. Acc: 60.00% |
# | Epoch: 33 | Train Loss: 1.015 | Train Acc: 62.62% | Val. Loss: 1.023 | Val. Acc: 60.00% |
# | Epoch: 34 | Train Loss: 1.014 | Train Acc: 62.62% | Val. Loss: 1.023 | Val. Acc: 60.00% |
# | Epoch: 35 | Train Loss: 1.014 | Train Acc: 62.62% | Val. Loss: 1.022 | Val. Acc: 60.00% |
# | Epoch: 36 | Train Loss: 1.013 | Train Acc: 62.62% | Val. Loss: 1.021 | Val. Acc: 60.00% |
# | Epoch: 37 | Train Loss: 1.013 | Train Acc: 62.62% | Val. Loss: 1.020 | Val. Acc: 60.00% |
# | Epoch: 38 | Train Loss: 1.010 | Train Acc: 62.56% | Val. Loss: 1.019 | Val. Acc: 60.00% |
# | Epoch: 39 | Train Loss: 1.010 | Train Acc: 62.62% | Val. Loss: 1.018 | Val. Acc: 60.00% |
# | Epoch: 40 | Train Loss: 1.008 | Train Acc: 62.62% | Val. Loss: 1.017 | Val. Acc: 60.00% |
# | Epoch: 41 | Train Loss: 1.009 | Train Acc: 62.62% | Val. Loss: 1.016 | Val. Acc: 60.00% |
# | Epoch: 42 | Train Loss: 1.007 | Train Acc: 62.62% | Val. Loss: 1.015 | Val. Acc: 60.00% |
# | Epoch: 43 | Train Loss: 1.006 | Train Acc: 62.62% | Val. Loss: 1.015 | Val. Acc: 60.00% |
# | Epoch: 44 | Train Loss: 1.005 | Train Acc: 62.62% | Val. Loss: 1.014 | Val. Acc: 60.00% |
# | Epoch: 45 | Train Loss: 1.003 | Train Acc: 62.62% | Val. Loss: 1.013 | Val. Acc: 60.00% |
# | Epoch: 46 | Train Loss: 1.004 | Train Acc: 62.62% | Val. Loss: 1.012 | Val. Acc: 60.00% |
# | Epoch: 47 | Train Loss: 1.003 | Train Acc: 62.62% | Val. Loss: 1.011 | Val. Acc: 60.00% |
# | Epoch: 48 | Train Loss: 1.001 | Train Acc: 62.62% | Val. Loss: 1.010 | Val. Acc: 60.00% |
# | Epoch: 49 | Train Loss: 1.001 | Train Acc: 62.62% | Val. Loss: 1.010 | Val. Acc: 60.00% |
# | Epoch: 50 | Train Loss: 1.000 | Train Acc: 62.62% | Val. Loss: 1.009 | Val. Acc: 60.00% |
# tensor(0.6000)

# %%
_, feature_valid, _, target_valid = train_valid_split(tweets_c_tensor, labels_c_tensor, 0.2)

test_model_C.eval()

with torch.no_grad():
  predictions = test_model_C(feature_valid).squeeze(1)
  acc = check_accuracy(predictions, target_valid, num_class=3)
  score = check_f1_score(predictions, target_valid, num_class=3)

print(f'Validation Accuracy: {acc:.4f}')
print(f'Validation F1 Score: {score:.4f}')
# Out:
# Validation Accuracy: 0.6000
# Validation F1 Score: 0.2500

# %%
def indices_to_labels(indices, label2index):
  labels = []
  for index in indices:
    for key, num in label2index.items():
      if index == num:
        labels.append(key)
  return labels

# %%
testA_dir = "/content/drive/My Drive/OffensEval/data/taskA/testset-taska.tsv"
testB_dir = "/content/drive/My Drive/OffensEval/data/taskB/testset-taskb.tsv"
testC_dir = "/content/drive/My Drive/OffensEval/data/taskC/test_set_taskc.tsv"

testA_data = pd.read_csv(testA_dir, sep='\t', header=0)
testA_ids = testA_data["id"].tolist()
testA_tweets = testA_data[["tweet"]]
clean_testA = copy.deepcopy(testA_tweets)

testB_data = pd.read_csv(testB_dir, sep='\t', header=0)
testB_ids = testB_data["id"].tolist()
testB_tweets = testB_data[["tweet"]]
clean_testB = copy.deepcopy(testB_tweets)

testC_data = pd.read_csv(testC_dir, sep='\t', header=0)
testC_ids = testC_data["id"].tolist()
testC_tweets = testC_data[["tweet"]]
clean_testC = copy.deepcopy(testC_tweets)

tqdm.pandas(desc="Cleaning Data for Task A...")
clean_testA['tweet'] = testA_tweets['tweet'].progress_apply(clean_data)
tqdm.pandas(desc="Tokenizing Data for Task A...")
clean_testA['tokens'] = clean_testA['tweet'].progress_apply(tokenize)
tqdm.pandas(desc="Removing Stop Words for Task A...")
clean_testA['tokens'] = clean_testA['tokens'].progress_apply(remove_stop_words)
tqdm.pandas(desc="Lemmatizing And Stemming for Task A...")
clean_testA['tokens'] = clean_testA['tokens'].progress_apply(lemmatize_and_stem)

tqdm.pandas(desc="Cleaning Data for Task B...")
clean_testB['tweet'] = testB_tweets['tweet'].progress_apply(clean_data)
tqdm.pandas(desc="Tokenizing Data for Task B...")
clean_testB['tokens'] = clean_testB['tweet'].progress_apply(tokenize)
tqdm.pandas(desc="Removing Stop Words for Task B...")
clean_testB['tokens'] = clean_testB['tokens'].progress_apply(remove_stop_words)
tqdm.pandas(desc="Lemmatizing And Stemming for Task B...")
clean_testB['tokens'] = clean_testB['tokens'].progress_apply(lemmatize_and_stem)

tqdm.pandas(desc="Cleaning Data for Task C...")
clean_testC['tweet'] = testC_tweets['tweet'].progress_apply(clean_data)
tqdm.pandas(desc="Tokenizing Data for Task C...")
clean_testC['tokens'] = clean_testC['tweet'].progress_apply(tokenize)
tqdm.pandas(desc="Removing Stop Words for Task C...")
clean_testC['tokens'] = clean_testC['tokens'].progress_apply(remove_stop_words)
tqdm.pandas(desc="Lemmatizing And Stemming for Task C...")
clean_testC['tokens'] = clean_testC['tokens'].progress_apply(lemmatize_and_stem)

tokenized_testA = clean_testA['tokens'].tolist()
tokenized_testB = clean_testB['tokens'].tolist()
tokenized_testC = clean_testC['tokens'].tolist()

testA_tensor = tweet_to_tensor(tokenized_testA, word2index, max_length)
testB_tensor = tweet_to_tensor(tokenized_testB, word2index, max_length)
testC_tensor = tweet_to_tensor(tokenized_testC, word2index, max_length)

print("Test A tensor size:")
print(testA_tensor.shape)
print("Test B tensor size:")
print(testB_tensor.shape)
print("Test C tensor size:")
print(testC_tensor.shape)
# Out:
# Cleaning Data for Task A...: 100%|██████████| 860/860 [00:00<00:00, 58087.24it/s]
# Tokenizing Data for Task A...: 100%|██████████| 860/860 [00:00<00:00, 5217.38it/s]
# Removing Stop Words for Task A...: 100%|██████████| 860/860 [00:00<00:00, 5948.87it/s]
# Lemmatizing And Stemming for Task A...: 100%|██████████| 860/860 [00:00<00:00, 1972.76it/s]
# Cleaning Data for Task B...: 100%|██████████| 240/240 [00:00<00:00, 38679.46it/s]
# Tokenizing Data for Task B...: 100%|██████████| 240/240 [00:00<00:00, 4958.73it/s]
# Removing Stop Words for Task B...: 100%|██████████| 240/240 [00:00<00:00, 5565.72it/s]
# Lemmatizing And Stemming for Task B...: 100%|██████████| 240/240 [00:00<00:00, 2053.27it/s]
# Cleaning Data for Task C...: 100%|██████████| 213/213 [00:00<00:00, 34241.18it/s]
# Tokenizing Data for Task C...: 100%|██████████| 213/213 [00:00<00:00, 4915.61it/s]
# Removing Stop Words for Task C...: 100%|██████████| 213/213 [00:00<00:00, 5311.04it/s]
# Lemmatizing And Stemming for Task C...: 100%|██████████| 213/213 [00:00<00:00, 1936.74it/s]
# Test A tensor size:
# torch.Size([860, 39])
# Test B tensor size:
# torch.Size([240, 39])
# Test C tensor size:
# torch.Size([213, 39])

# %%
test_model_A.eval()

with torch.no_grad():
  output = test_model_A(testA_tensor).squeeze(1)
  output = torch.round(torch.sigmoid(output))

preds_testA = indices_to_labels(output, a2index)

taskA_df = pd.DataFrame(testA_ids, columns=['id'])
taskA_df['predict'] = preds_testA
taskA_df.to_csv('testA.csv', header=False, index=False)

# %%
test_model_B.eval()

with torch.no_grad():
  output = test_model_B(testB_tensor).squeeze(1)
  output = torch.round(torch.sigmoid(output))

preds_testB = indices_to_labels(output, b2index)

taskB_df = pd.DataFrame(testB_ids, columns=['id'])
taskB_df['predict'] = preds_testB
taskB_df.to_csv('testB.csv', header=False, index=False)

# %%
test_model_C.eval()

with torch.no_grad():
  output = test_model_C(testC_tensor).squeeze(1)
  output = F.log_softmax(output)
  output = output.data.max(1)[1].numpy()

preds_testC = indices_to_labels(output, c2index)

taskC_df = pd.DataFrame(testC_ids, columns=['id'])
taskC_df['predict'] = preds_testC
taskC_df.to_csv('testC.csv', header=False, index=False)
